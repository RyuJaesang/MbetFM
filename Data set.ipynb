# %%
import pandas as pd

list_data = pd.read_csv('bi_data.csv')
list_data.head()
# Out:
#                     타임스탬프  \
# 0  2019. 11. 7 오후 6:03:37
# 1  2019. 11. 7 오후 6:04:10
# 2  2019. 11. 7 오후 6:10:23
# 3  2019. 11. 7 오후 6:10:27
# 4  2019. 11. 7 오후 6:10:44
#
#   What genre of music do you most likely to listen to? /가장 좋아하는 음악 장르는 무엇입니까?(Select 3 / 3가지 선택)  \
# 0       Pop / Idol (팝/아이돌), Ballad (발라드), Dance (댄스)
# 1  Rap/ Hip Hop (랩/힙합), R&B / Soul (R&B/소울), Rock...
# 2         Pop (팝), Ballad (발라드), R&B / Soul (R&B/소울)
# 3           Pop (팝), Rap/ Hip Hop (랩/힙합), Indie (인디)
# 4               Idol (아이돌), Ballad (발라드), Dance (댄스)
#
#   What kind of fashion style do you like the most? / 가장 좋아하는 패션 스타일은 무엇입니까? (Select 3 / 3가지 선택)  \
# 0  Workwear (워크웨어륵) (constructed of sturdy fabric...
# 1  Casual (캐주얼룩), Workwear (워크웨어륵) (constructed o...
# 2  Casual (캐주얼룩), Workwear (워크웨어륵) (constructed o...
# 3  Casual (캐주얼룩), Workwear (워크웨어륵) (constructed o...
# 4  Casual (캐주얼룩), Workwear (워크웨어륵) (constructed o...
#
#   What kind of art performances do you like the most? / 가장 좋아하는 공연은 무엇입니까?  \
# 0                            Music Performances (음악)
# 1                            Music Performances (음악)
# 2                            Music Performances (음악)
# 3                            Music Performances (음악)
# 4                                     Musicals (뮤지컬)
#
#   What kind of art exhibitions do you like the most? / 가장 좋아하는 전시회는 무엇입니까?
# 0                                    Sculptures (조각)
# 1                                     Paintings (회화)
# 2                                   Photography (사진)
# 3                                   Art Design (디자인)
# 4                                   Art Design (디자인)

# %%
import pandas as pd

list_data = pd.read_csv('bi_data.csv')
list_data
# Out:
#                         타임스탬프  \
# 0      2019. 11. 7 오후 6:03:37
# 1      2019. 11. 7 오후 6:04:10
# 2      2019. 11. 7 오후 6:10:23
# 3      2019. 11. 7 오후 6:10:27
# 4      2019. 11. 7 오후 6:10:44
# ..                        ...
# 161   2019. 11. 15 오후 4:07:30
# 162   2019. 11. 15 오후 4:36:31
# 163   2019. 11. 15 오후 5:51:09
# 164   2019. 11. 16 오후 5:16:58
# 165  2019. 11. 19 오전 11:42:31
#
#     What genre of music do you most likely to listen to? /가장 좋아하는 음악 장르는 무엇입니까?(Select 3 / 3가지 선택)  \
# 0         Pop / Idol (팝/아이돌), Ballad (발라드), Dance (댄스)
# 1    Rap/ Hip Hop (랩/힙합), R&B / Soul (R&B/소울), Rock...
# 2           Pop (팝), Ballad (발라드), R&B / Soul (R&B/소울)
# 3             Pop (팝), Rap/ Hip Hop (랩/힙합), Indie (인디)
# 4                 Idol (아이돌), Ballad (발라드), Dance (댄스)
# ..                                                 ...
# 161         Pop (팝), Ballad (발라드), R&B / Soul (R&B/소울)
# 162           Pop (팝), R&B / Soul (R&B/소울), Indie (인디)
# 163           Pop (팝), Idol (아이돌), R&B / Soul (R&B/소울)
# 164  Pop (팝), Rap/ Hip Hop (랩/힙합), R&B / Soul (R&B/소울)
# 165                 Idol (아이돌), Dance (댄스), Indie (인디)
#
#     What kind of fashion style do you like the most? / 가장 좋아하는 패션 스타일은 무엇입니까? (Select 3 / 3가지 선택)  \
# 0    Workwear (워크웨어륵) (constructed of sturdy fabric...
# 1    Casual (캐주얼룩), Workwear (워크웨어륵) (constructed o...
# 2    Casual (캐주얼룩), Workwear (워크웨어륵) (constructed o...
# 3    Casual (캐주얼룩), Workwear (워크웨어륵) (constructed o...
# 4    Casual (캐주얼룩), Workwear (워크웨어륵) (constructed o...
# ..                                                 ...
# 161        Casual (캐주얼룩), Street (스트릿룩), Grunge (그런지룩)
# 162          Street (스트릿룩), Vintage (빈티지룩), Chic (시크룩)
# 163  Workwear (워크웨어륵) (constructed of sturdy fabric...
# 164        Casual (캐주얼룩), Street (스트릿룩), Grunge (그런지룩)
# 165  Casual (캐주얼룩), Workwear (워크웨어륵) (constructed o...
#
#     What kind of art performances do you like the most? / 가장 좋아하는 공연은 무엇입니까?  \
# 0                              Music Performances (음악)
# 1                              Music Performances (음악)
# 2                              Music Performances (음악)
# 3                              Music Performances (음악)
# 4                                       Musicals (뮤지컬)
# ..                                                 ...
# 161                            Music Performances (음악)
# 162                                     Musicals (뮤지컬)
# 163                            Music Performances (음악)
# 164                            Music Performances (음악)
# 165                            Music Performances (음악)
#
#     What kind of art exhibitions do you like the most? / 가장 좋아하는 전시회는 무엇입니까?
# 0                                      Sculptures (조각)
# 1                                       Paintings (회화)
# 2                                     Photography (사진)
# 3                                     Art Design (디자인)
# 4                                     Art Design (디자인)
# ..                                                 ...
# 161                                     Paintings (회화)
# 162                                     Paintings (회화)
# 163                                   Art Design (디자인)
# 164                                     Paintings (회화)
# 165                                   Photography (사진)
#
# [166 rows x 5 columns]

# %%
# import pandas as pd
import pandas as pd
# load the data with pd.read_csv
gapminder = pd.read_csv("bi_data.csv")
# check the data frame info
print(gapminder.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166 entries, 0 to 165
# Data columns (total 5 columns):
# 타임스탬프                                                                                             166 non-null object
# What genre of music do you most likely to listen to? /가장 좋아하는 음악 장르는 무엇입니까?(Select 3 / 3가지 선택)    166 non-null object
# What kind of fashion style do you like the most? / 가장 좋아하는 패션 스타일은 무엇입니까? (Select 3 / 3가지 선택)     166 non-null object
# What kind of art performances do you like the most? / 가장 좋아하는 공연은 무엇입니까?                          166 non-null object
# What kind of art exhibitions do you like the most? / 가장 좋아하는 전시회는 무엇입니까?                          166 non-null object
# dtypes: object(5)
# memory usage: 6.6+ KB
# None

# %%
# import pandas as pd
import pandas as pd
# load the data with pd.read_csv
gapminder = pd.read_csv("bi_data1.csv")
# check the data frame info
print(gapminder.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166 entries, 0 to 165
# Data columns (total 4 columns):
# What genre of music do you most likely to listen to?     166 non-null object
# What kind of fashion style do you like the most?         166 non-null object
# What kind of art performances do you like the most?      165 non-null object
# What kind of art exhibitions do you like the most?       163 non-null object
# dtypes: object(4)
# memory usage: 5.3+ KB
# None

# %%
gapminder['What genre of music do you most likely to listen to? '].unique()
# Out:
# array(['Pop / Idol , Ballad, Dance',
#        'Rap/ Hip Hop, R&B / Soul, Rock / Metal',
#        'Pop, Ballad, R&B / Soul', 'Pop, Rap/Hiphop, Indie',
#        'Idol, Ballad, Dance', 'Pop, Idol, Ballad', 'Pop, Ballad, Indie',
#        'Pop, Dance, Rock / Metal', 'Pop, Rap/Hiphop, R&B / Soul',
#        'Pop, Ballad, Rap/Hiphop', 'Pop, Indie, Rock / Metal',
#        'Rap/Hiphop, R&B / Soul, Indie', 'Rap/Hiphop, Indie, Rock / Metal',
#        'Ballad, Rap/Hiphop, R&B / Soul', 'Pop, Ballad',
#        'Pop, Rap/Hiphop, Rock / Metal', 'Ballad, Rap/Hiphop, Indie',
#        'Pop, Ballad, Dance', 'Pop, R&B / Soul, Rock / Metal',
#        'Dance, Rap/Hiphop, Rock / Metal', 'Idol, Ballad, Indie',
#        'Idol, Dance, R&B / Soul', 'Pop, Idol, Dance',
#        'Pop, Idol, Rock / Metal', 'Idol, Dance, Rap/Hiphop',
#        'Pop, R&B / Soul, Indie', 'Idol, Ballad, Rap/Hiphop',
#        'Pop, Dance, R&B / Soul',
#        'Pop, Ballad, Instrumental, orchestral, ',
#        'Idol, Ballad, R&B / Soul', 'Pop, Dance, Kpop ',
#        'Pop, Indie, TWICE', 'Idol, Dance, Rock / Metal',
#        'Pop, Idol, Trot (¡??‰\xad?¡??)', 'Pop, Idol, R&B / Soul',
#        'Pop, Idol, Rap/Hiphop', 'Ballad, R&B / Soul, Chinese',
#        'Pop, Ballad, Rock / Metal', 'Pop, Rock / Metal, EDM',
#        'Ballad, Dance, Rap/Hiphop', 'Pop, Dance, Indie',
#        'Ballad, R&B / Soul, Indie', 'Dance, Rap/Hiphop, R&B / Soul',
#        'Pop, Rock / Metal, ¡\x81?‰??\x8d?\x9d',
#        'Ballad, Dance, R&B / Soul', 'Pop, Dance, Rap/Hiphop',
#        'Pop, Idol, Indie', 'Dance, Rap/Hiphop, Indie',
#        'Pop, Indie, alternative', 'Idol, Rap/Hiphop, R&B / Soul',
#        'Pop, Indie, Lofi ', 'Idol, R&B / Soul, Indie',
#        'Pop, Rap/Hiphop, EDM', 'Idol, Dance, Indie'], dtype=object)

# %%
gapminder['What kind of fashion style do you like the most? '].unique()
# Out:
# array(['Workwear, Techwear, Dandy', 'Casual, Workwear, Street',
#        'Casual, Workwear, Chic', 'Casual, Workwear, Dandy',
#        'Street, Goth, Dandy', 'Casual, Street, Vintage',
#        'Workwear, Street, Dandy', 'Casual, Street, Dandy',
#        'Casual, Grunge, Dandy', 'Casual, Workwear, Techwear',
#        'Street, Grunge, Techwear', 'Street, Vintage, Techwear',
#        'Goth, Techwear', 'Casual, Athleisure, Street',
#        'Casual, Street, Chic', 'Casual, Street, Grunge',
#        'Casual, Workwear, Grunge', 'Workwear, Street, Techwear',
#        'Casual, Street, Techwear', 'Workwear, Preppy, Dandy',
#        'Casual, Vintage, Chic', 'Workwear, Street, Chic',
#        'Workwear, Chic, Grunge', 'Casual, Bohemian, Dandy',
#        'Casual, Workwear, Athleisure', 'Casual, Techwear, Dandy',
#        'Casual, Athleisure, Chic', 'Street, Chic, Bohemian',
#        'Casual, Workwear, Vintage', 'Athleisure, Street, Grunge',
#        'Casual, Workwear, Preppy', 'Casual, Chic, Preppy',
#        'Casual, Chic, Bohemian', 'Casual, Athleisure, Vintage',
#        'Casual, Vintage, Dandy', 'Street, Vintage, Chic',
#        'Casual, Workwear, Goth', 'Athleisure, Preppy, Bohemian',
#        'Workwear, Vintage, Bohemian', 'Casual, Street, Preppy',
#        'Chic, Preppy, Bohemian', 'Casual, Chic, Grunge',
#        'Street, Vintage, Bohemian', 'Workwear, Athleisure, Street',
#        'Vintage, Chic, seethrough loom', 'Casual, Chic, Dandy',
#        'Casual, Workwear, Bohemian', 'Casual, Vintage, Preppy',
#        'Workwear, Techwear, ', 'Workwear, Chic, Preppy',
#        'Casual, Preppy, Grunge', 'Vintage, Chic, Bohemian',
#        'Street, Grunge,', 'Chic, Preppy, Grunge',
#        'Vintage, Techwear, Dandy', 'Street, Vintage, Grunge',
#        'Street, Chic, Grunge', 'Athleisure, Street, Dandy',
#        'Street, Chic, Techwear', 'Workwear, Athleisure, Chic'],
#       dtype=object)

# %%
dataset=([['Pop' , 'Ballad', 'Dance'],
       ['Rap/Hip Hop', 'R&B / Soul', 'Rock / Metal'],
       ['Pop', 'Ballad', 'R&B / Soul'], ['Pop', 'Rap/Hiphop', 'Indie'],
       ['Idol', 'Ballad', 'Dance'], ['Pop', 'Idol', 'Ballad'], ['Pop', 'Ballad', 'Indie'],
       ['Pop', 'Dance', 'Rock / Metal'], ['Pop', 'Rap/Hiphop', 'R&B / Soul'],
       ['Pop', 'Ballad', 'Rap/Hiphop'], ['Pop', 'Indie', 'Rock / Metal'],
       ['Rap/Hiphop', 'R&B / Soul', 'Indie'], ['Rap/Hiphop', 'Indie', 'Rock / Metal'],
       ['Ballad', 'Rap/Hiphop', 'R&B / Soul'], ['Pop', 'Ballad'],
       ['Pop', 'Rap/Hiphop', 'Rock / Metal'], ['Ballad', 'Rap/Hiphop', 'Indie'],
       ['Pop', 'Ballad', 'Dance'], ['Pop', 'R&B / Soul', 'Rock / Metal'],
       ['Dance', 'Rap/Hiphop', 'Rock / Metal'], ['Idol', 'Ballad', 'Indie'],
       ['Idol', 'Dance', 'R&B / Soul'], ['Pop', 'Idol', 'Dance'],
       ['Pop', 'Idol', 'Rock / Metal'], ['Idol', 'Dance', 'Rap/Hiphop'],
       ['Pop', 'R&B / Soul', 'Indie'], ['Idol', 'Ballad', 'Rap/Hiphop'],
       ['Pop', 'Dance', 'R&B / Soul'],
       ['Pop', 'Ballad', 'Instrumental', 'orchestral'],
       ['Idol', 'Ballad', 'R&B / Soul'], ['Pop', 'Dance'],
       ['Pop', 'Indie'], ['Idol', 'Dance', 'Rock / Metal'],
       ['Pop', 'Idol', 'Trot'], ['Pop', 'Idol', 'R&B / Soul'],
       ['Pop', 'Idol', 'Rap/Hiphop'], ['Ballad', 'R&B / Soul', 'Chinese'],
       ['Pop', 'Ballad', 'Rock / Metal'], ['Pop', 'Rock / Metal', 'EDM'],
       ['Ballad', 'Dance', 'Rap/Hiphop'], ['Pop', 'Dance', 'Indie'],
       ['Ballad', 'R&B / Soul', 'Indie'], ['Dance', 'Rap/Hiphop', 'R&B / Soul'],
       ['Pop', 'Rock / Metal'],
       ['Ballad', 'Dance', 'R&B / Soul'], ['Pop', 'Dance', 'Rap/Hiphop'],
       ['Pop', 'Idol', 'Indie'], ['Dance', 'Rap/Hiphop', 'Indie'],
       ['Pop', 'Indie', 'alternative'], ['Idol', 'Rap/Hiphop', 'R&B / Soul'],
       ['Pop', 'Indie', 'Lofi '], ['Idol', 'R&B / Soul', 'Indie'],
       ['Pop', 'Rap/Hiphop', 'EDM'], ['Idol', 'Dance', 'Indie']])

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#     Ballad  Chinese  Dance    EDM   Idol  Indie  Instrumental  Lofi     Pop  \
# 0     True    False   True  False  False  False         False  False   True
# 1    False    False  False  False  False  False         False  False  False
# 2     True    False  False  False  False  False         False  False   True
# 3    False    False  False  False  False   True         False  False   True
# 4     True    False   True  False   True  False         False  False  False
# 5     True    False  False  False   True  False         False  False   True
# 6     True    False  False  False  False   True         False  False   True
# 7    False    False   True  False  False  False         False  False   True
# 8    False    False  False  False  False  False         False  False   True
# 9     True    False  False  False  False  False         False  False   True
# 10   False    False  False  False  False   True         False  False   True
# 11   False    False  False  False  False   True         False  False  False
# 12   False    False  False  False  False   True         False  False  False
# 13    True    False  False  False  False  False         False  False  False
# 14    True    False  False  False  False  False         False  False   True
# 15   False    False  False  False  False  False         False  False   True
# 16    True    False  False  False  False   True         False  False  False
# 17    True    False   True  False  False  False         False  False   True
# 18   False    False  False  False  False  False         False  False   True
# 19   False    False   True  False  False  False         False  False  False
# 20    True    False  False  False   True   True         False  False  False
# 21   False    False   True  False   True  False         False  False  False
# 22   False    False   True  False   True  False         False  False   True
# 23   False    False  False  False   True  False         False  False   True
# 24   False    False   True  False   True  False         False  False  False
# 25   False    False  False  False  False   True         False  False   True
# 26    True    False  False  False   True  False         False  False  False
# 27   False    False   True  False  False  False         False  False   True
# 28    True    False  False  False  False  False          True  False   True
# 29    True    False  False  False   True  False         False  False  False
# 30   False    False   True  False  False  False         False  False   True
# 31   False    False  False  False  False   True         False  False   True
# 32   False    False   True  False   True  False         False  False  False
# 33   False    False  False  False   True  False         False  False   True
# 34   False    False  False  False   True  False         False  False   True
# 35   False    False  False  False   True  False         False  False   True
# 36    True     True  False  False  False  False         False  False  False
# 37    True    False  False  False  False  False         False  False   True
# 38   False    False  False   True  False  False         False  False   True
# 39    True    False   True  False  False  False         False  False  False
# 40   False    False   True  False  False   True         False  False   True
# 41    True    False  False  False  False   True         False  False  False
# 42   False    False   True  False  False  False         False  False  False
# 43   False    False  False  False  False  False         False  False   True
# 44    True    False   True  False  False  False         False  False  False
# 45   False    False   True  False  False  False         False  False   True
# 46   False    False  False  False   True   True         False  False   True
# 47   False    False   True  False  False   True         False  False  False
# 48   False    False  False  False  False   True         False  False   True
# 49   False    False  False  False   True  False         False  False  False
# 50   False    False  False  False  False   True         False   True   True
# 51   False    False  False  False   True   True         False  False  False
# 52   False    False  False   True  False  False         False  False   True
# 53   False    False   True  False   True   True         False  False  False
#
#     R&B / Soul  Rap/Hip Hop  Rap/Hiphop  Rock / Metal   Trot  alternative  \
# 0        False        False       False         False  False        False
# 1         True         True       False          True  False        False
# 2         True        False       False         False  False        False
# 3        False        False        True         False  False        False
# 4        False        False       False         False  False        False
# 5        False        False       False         False  False        False
# 6        False        False       False         False  False        False
# 7        False        False       False          True  False        False
# 8         True        False        True         False  False        False
# 9        False        False        True         False  False        False
# 10       False        False       False          True  False        False
# 11        True        False        True         False  False        False
# 12       False        False        True          True  False        False
# 13        True        False        True         False  False        False
# 14       False        False       False         False  False        False
# 15       False        False        True          True  False        False
# 16       False        False        True         False  False        False
# 17       False        False       False         False  False        False
# 18        True        False       False          True  False        False
# 19       False        False        True          True  False        False
# 20       False        False       False         False  False        False
# 21        True        False       False         False  False        False
# 22       False        False       False         False  False        False
# 23       False        False       False          True  False        False
# 24       False        False        True         False  False        False
# 25        True        False       False         False  False        False
# 26       False        False        True         False  False        False
# 27        True        False       False         False  False        False
# 28       False        False       False         False  False        False
# 29        True        False       False         False  False        False
# 30       False        False       False         False  False        False
# 31       False        False       False         False  False        False
# 32       False        False       False          True  False        False
# 33       False        False       False         False   True        False
# 34        True        False       False         False  False        False
# 35       False        False        True         False  False        False
# 36        True        False       False         False  False        False
# 37       False        False       False          True  False        False
# 38       False        False       False          True  False        False
# 39       False        False        True         False  False        False
# 40       False        False       False         False  False        False
# 41        True        False       False         False  False        False
# 42        True        False        True         False  False        False
# 43       False        False       False          True  False        False
# 44        True        False       False         False  False        False
# 45       False        False        True         False  False        False
# 46       False        False       False         False  False        False
# 47       False        False        True         False  False        False
# 48       False        False       False         False  False         True
# 49        True        False        True         False  False        False
# 50       False        False       False         False  False        False
# 51        True        False       False         False  False        False
# 52       False        False        True         False  False        False
# 53       False        False       False         False  False        False
#
#     orchestral
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28        True
# 29       False
# 30       False
# 31       False
# 32       False
# 33       False
# 34       False
# 35       False
# 36       False
# 37       False
# 38       False
# 39       False
# 40       False
# 41       False
# 42       False
# 43       False
# 44       False
# 45       False
# 46       False
# 47       False
# 48       False
# 49       False
# 50       False
# 51       False
# 52       False
# 53       False

# %%
from mlxtend.frequent_patterns import fpgrowth

fpgrowth(df, min_support=0.1, use_colnames=True)
# Out:
#      support              itemsets
# 0   0.592593                 (Pop)
# 1   0.351852              (Ballad)
# 2   0.333333               (Dance)
# 3   0.314815          (R&B / Soul)
# 4   0.222222        (Rock / Metal)
# 5   0.333333          (Rap/Hiphop)
# 6   0.314815               (Indie)
# 7   0.314815                (Idol)
# 8   0.166667         (Pop, Ballad)
# 9   0.148148          (Pop, Dance)
# 10  0.111111   (Dance, Rap/Hiphop)
# 11  0.111111  (R&B / Soul, Ballad)
# 12  0.111111     (Pop, R&B / Soul)
# 13  0.148148   (Pop, Rock / Metal)
# 14  0.129630     (Pop, Rap/Hiphop)
# 15  0.166667          (Pop, Indie)
# 16  0.111111         (Dance, Idol)
# 17  0.129630           (Pop, Idol)

# %%
from mlxtend.frequent_patterns import fpgrowth

fpgrowth(df, min_support=0.15, use_colnames=True)
# Out:
#     support        itemsets
# 0  0.592593           (Pop)
# 1  0.351852        (Ballad)
# 2  0.333333         (Dance)
# 3  0.314815    (R&B / Soul)
# 4  0.222222  (Rock / Metal)
# 5  0.333333    (Rap/Hiphop)
# 6  0.314815         (Indie)
# 7  0.314815          (Idol)
# 8  0.166667   (Pop, Ballad)
# 9  0.166667    (Pop, Indie)

# %%
fashion=([['Workwear', 'Techwear', 'Dandy'], ['Casual', 'Workwear', 'Street'],
       ['Casual', 'Workwear', 'Chic'], ['Casual', 'Workwear', 'Dandy'],
       ['Street', 'Goth', 'Dandy'], ['Casual', 'Street', 'Vintage'],
       ['Workwear', 'Street', 'Dandy'], ['Casual', 'Street', 'Dandy'],
       ['Casual', 'Grunge', 'Dandy'], ['Casual', 'Workwear', 'Techwear'],
       ['Street', 'Grunge', 'Techwear'], ['Street', 'Vintage', 'Techwear'],
       ['Goth', 'Techwear'], ['Casual', 'Athleisure', 'Street'],
       ['Casual', 'Street', 'Chic'], ['Casual', 'Street', 'Grunge'],
       ['Casual', 'Workwear', 'Grunge'], ['Workwear', 'Street', 'Techwear'],
       ['Casual', 'Street', 'Techwear'], ['Workwear', 'Preppy', 'Dandy'],
       ['Casual', 'Vintage', 'Chic'], ['Workwear', 'Street', 'Chic'],
       ['Workwear', 'Chic', 'Grunge'], ['Casual', 'Bohemian', 'Dandy'],
       ['Casual', 'Workwear', 'Athleisure'], ['Casual', 'Techwear', 'Dandy'],
       ['Casual', 'Athleisure', 'Chic'], ['Street', 'Chic', 'Bohemian'],
       ['Casual', 'Workwear', 'Vintage'], ['Athleisure', 'Street', 'Grunge'],
       ['Casual', 'Workwear', 'Preppy'], ['Casual', 'Chic', 'Preppy'],
       ['Casual', 'Chic', 'Bohemian'], ['Casual', 'Athleisure', 'Vintage'],
       ['Casual', 'Vintage', 'Dandy'], ['Street', 'Vintage', 'Chic'],
       ['Casual', 'Workwear', 'Goth'], ['Athleisure', 'Preppy', 'Bohemian'],
       ['Workwear', 'Vintage', 'Bohemian'], ['Casual', 'Street', 'Preppy'],
       ['Chic', 'Preppy', 'Bohemian'], ['Casual', 'Chic', 'Grunge'],
       ['Street', 'Vintage', 'Bohemian'], ['Workwear', 'Athleisure', 'Street'],
       ['Vintage', 'Chic', 'seethrough loom'], ['Casual', 'Chic', 'Dandy'],
       ['Casual', 'Workwear', 'Bohemian'], ['Casual', 'Vintage', 'Preppy'],
       ['Workwear', 'Techwear'], ['Workwear', 'Chic', 'Preppy'],
       ['Casual', 'Preppy', 'Grunge'], ['Vintage', 'Chic', 'Bohemian'],
       ['Street', 'Grunge'], ['Chic', 'Preppy', 'Grunge'],
       ['Vintage', 'Techwear', 'Dandy'], ['Street', 'Vintage', 'Grunge'],
       ['Street', 'Chic', 'Grunge'], ['Athleisure', 'Street', 'Dandy'],
       ['Street', 'Chic', 'Techwear'], ['Workwear', 'Athleisure', 'Chic']])

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(fashion).transform(fashion)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#     Athleisure  Bohemian  Casual   Chic  Dandy   Goth  Grunge  Preppy  Street  \
# 0        False     False   False  False   True  False   False   False   False
# 1        False     False    True  False  False  False   False   False    True
# 2        False     False    True   True  False  False   False   False   False
# 3        False     False    True  False   True  False   False   False   False
# 4        False     False   False  False   True   True   False   False    True
# 5        False     False    True  False  False  False   False   False    True
# 6        False     False   False  False   True  False   False   False    True
# 7        False     False    True  False   True  False   False   False    True
# 8        False     False    True  False   True  False    True   False   False
# 9        False     False    True  False  False  False   False   False   False
# 10       False     False   False  False  False  False    True   False    True
# 11       False     False   False  False  False  False   False   False    True
# 12       False     False   False  False  False   True   False   False   False
# 13        True     False    True  False  False  False   False   False    True
# 14       False     False    True   True  False  False   False   False    True
# 15       False     False    True  False  False  False    True   False    True
# 16       False     False    True  False  False  False    True   False   False
# 17       False     False   False  False  False  False   False   False    True
# 18       False     False    True  False  False  False   False   False    True
# 19       False     False   False  False   True  False   False    True   False
# 20       False     False    True   True  False  False   False   False   False
# 21       False     False   False   True  False  False   False   False    True
# 22       False     False   False   True  False  False    True   False   False
# 23       False      True    True  False   True  False   False   False   False
# 24        True     False    True  False  False  False   False   False   False
# 25       False     False    True  False   True  False   False   False   False
# 26        True     False    True   True  False  False   False   False   False
# 27       False      True   False   True  False  False   False   False    True
# 28       False     False    True  False  False  False   False   False   False
# 29        True     False   False  False  False  False    True   False    True
# 30       False     False    True  False  False  False   False    True   False
# 31       False     False    True   True  False  False   False    True   False
# 32       False      True    True   True  False  False   False   False   False
# 33        True     False    True  False  False  False   False   False   False
# 34       False     False    True  False   True  False   False   False   False
# 35       False     False   False   True  False  False   False   False    True
# 36       False     False    True  False  False   True   False   False   False
# 37        True      True   False  False  False  False   False    True   False
# 38       False      True   False  False  False  False   False   False   False
# 39       False     False    True  False  False  False   False    True    True
# 40       False      True   False   True  False  False   False    True   False
# 41       False     False    True   True  False  False    True   False   False
# 42       False      True   False  False  False  False   False   False    True
# 43        True     False   False  False  False  False   False   False    True
# 44       False     False   False   True  False  False   False   False   False
# 45       False     False    True   True   True  False   False   False   False
# 46       False      True    True  False  False  False   False   False   False
# 47       False     False    True  False  False  False   False    True   False
# 48       False     False   False  False  False  False   False   False   False
# 49       False     False   False   True  False  False   False    True   False
# 50       False     False    True  False  False  False    True    True   False
# 51       False      True   False   True  False  False   False   False   False
# 52       False     False   False  False  False  False    True   False    True
# 53       False     False   False   True  False  False    True    True   False
# 54       False     False   False  False   True  False   False   False   False
# 55       False     False   False  False  False  False    True   False    True
# 56       False     False   False   True  False  False    True   False    True
# 57        True     False   False  False   True  False   False   False    True
# 58       False     False   False   True  False  False   False   False    True
# 59        True     False   False   True  False  False   False   False   False
#
#     Techwear  Vintage  Workwear  seethrough loom
# 0       True    False      True            False
# 1      False    False      True            False
# 2      False    False      True            False
# 3      False    False      True            False
# 4      False    False     False            False
# 5      False     True     False            False
# 6      False    False      True            False
# 7      False    False     False            False
# 8      False    False     False            False
# 9       True    False      True            False
# 10      True    False     False            False
# 11      True     True     False            False
# 12      True    False     False            False
# 13     False    False     False            False
# 14     False    False     False            False
# 15     False    False     False            False
# 16     False    False      True            False
# 17      True    False      True            False
# 18      True    False     False            False
# 19     False    False      True            False
# 20     False     True     False            False
# 21     False    False      True            False
# 22     False    False      True            False
# 23     False    False     False            False
# 24     False    False      True            False
# 25      True    False     False            False
# 26     False    False     False            False
# 27     False    False     False            False
# 28     False     True      True            False
# 29     False    False     False            False
# 30     False    False      True            False
# 31     False    False     False            False
# 32     False    False     False            False
# 33     False     True     False            False
# 34     False     True     False            False
# 35     False     True     False            False
# 36     False    False      True            False
# 37     False    False     False            False
# 38     False     True      True            False
# 39     False    False     False            False
# 40     False    False     False            False
# 41     False    False     False            False
# 42     False     True     False            False
# 43     False    False      True            False
# 44     False     True     False             True
# 45     False    False     False            False
# 46     False    False      True            False
# 47     False     True     False            False
# 48      True    False      True            False
# 49     False    False      True            False
# 50     False    False     False            False
# 51     False     True     False            False
# 52     False    False     False            False
# 53     False    False     False            False
# 54      True     True     False            False
# 55     False     True     False            False
# 56     False    False     False            False
# 57     False    False     False            False
# 58      True    False     False            False
# 59     False    False      True            False

# %%
from mlxtend.frequent_patterns import fpgrowth

fpgrowth(df, min_support=0.15, use_colnames=True)
# Out:
#      support            itemsets
# 0   0.350000          (Workwear)
# 1   0.216667             (Dandy)
# 2   0.183333          (Techwear)
# 3   0.500000            (Casual)
# 4   0.400000            (Street)
# 5   0.333333              (Chic)
# 6   0.233333           (Vintage)
# 7   0.200000            (Grunge)
# 8   0.150000        (Athleisure)
# 9   0.166667            (Preppy)
# 10  0.150000          (Bohemian)
# 11  0.166667  (Workwear, Casual)

# %%
import csv
with open('perform.csv', newline='') as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)
# Out:
# ['ï»¿Music Performances']
# ['Music Performances']
# ['Music Performances']
# ['Music Performances']
# ['Musicals']
# ['Musicals']
# ['Music Performances']
# ['Musicals']
# ['Musicals']
# ['Musicals']
# ['Theater']
# ['Interdisciplinary Arts']
# ['Music Performances']
# ['Musicals']
# ['Music Performances']
# ['Music Performances']
# ['Interdisciplinary Arts']
# ['Music Performances']
# ['Music Performances']
# ['Music Performances']
# ['Dance']
# ['Music Performances']
# ['Theater']
# ['Musicals']
# ['Music Performances']
# ['Music Performances']
# ['Traditional Art']
# ['Music Performances']
# ['Musicals']
# ['Music Performances']
# ['Dance']
# ['Theater']
# ['Music Performances']
# ['Music Performances']
# ['Music Performances']
# ['Theater']
# ['Musicals']
# ['Music Performances']
# ['Dance']
# ['Dance']
# ['Music Performances']
# ['Music Performances']
# ['Dance']
# ['Dance']
# ['Music Performances']
# ['Musicals']
# ['Music Performances']
# ['Music Performances']
# ['Dance']
# ['Dance']
# ['Music Performances']
# ['Music Performances']
# ['Dance']
# ['Musicals']
# ['Musicals']
# ['Musicals']
# ['Musicals']
# ['Dance']
# ['Dance']
# ['Traditional Art']
# ['Music Performances']
# ['Music Performances']
# ['Music Performances']
# ['Theater']
# ['Music Performances']
# ['Music Performances']
# ['Music Performances']
# ['Dance']
# ['Dance']
# ['Traditional Art']
# ['Music Performances']
# ['Musicals']
# ['Theater']
# ['Music Performances']
# ['Theater']
# ['Dance']
# ['Music Performances']
# ['Music Performances']
# ['Dance']
# ['Dance']
# ['Music Performances']
# ['Music Performances']
# ['Food']
# ['Dance']
# ['Theater']
# ['Music Performances']
# ['Musicals']
# ['Music Performances']
# ['Music Performances']
# ['Music Performances']
# ['Musicals']
# ['Music Performances']
# ['Musicals']
# ['Music Performances']
# ['Music Performances']
# ['Theater']
# ['Music Performances']
# ['Theater']
# ['Music Performances']
# ['Music Performances']
# ['Musicals']
# ['Musicals']
# ['Dance']
# ['Music Performances']
# ['Music Performances']
# ['Musicals']
# ['Theater']
# ['Music Performances']
# ['Music Performances']
# ['Musicals']
# ['Theater']
# ['Music Performances']
# ['Musicals']
# ['Musicals']
# ['Theater']
# ['Theater']
# ['Musicals']
# ['Musicals']
# ['Musicals']
# ['Musicals']
# ['Musicals']
# ['Music Performances']
# ['Music Performances']
# ['Musicals']
# ['Musicals']
# ['Theater']
# ['Music Performances']
# ['Musicals']
# ['Theater']
# ['Music Performances']
# ['Music Performances']
# ['Musicals']
# ['Musicals']
# ['Music Performances']
# ['Musicals']
# ['Music Performances']
# ['Musicals']
# ['Musicals']
# ['Music Performances']
# ['Theater']
# ['Musicals']
# ['Music Performances']
# ['Music Performances']
# ['Dance']
# ['Music Performances']
# ['Dance']
# ['Dance']
# ['Music Performances']
# ['Dance']
# ['Dance']
# ['Music Performances']
# ['Dance']
# ['Interdisciplinary Arts']
# ['Musicals']
# ['Music Performances']
# ['Music Performances']
# ['Music Performances']
# ['Animation']
# ['Theater']
# ['Music Performances']
# ['Music Performances']
# ['Musicals']
# ['Music Performances']
# ['Music Performances']
# ['Music Performances']

# %%
perform=([['Music Performances'],
['Music Performances'],
['Music Performances'],
['Music Performances'],
['Musicals'],
['Musicals'],
['Music Performances'],
['Musicals'],
['Musicals'],
['Musicals'],
['Theater'],
['Interdisciplinary Arts'],
['Music Performances'],
['Musicals'],
['Music Performances'],
['Music Performances'],
['Interdisciplinary Arts'],
['Music Performances'],
['Music Performances'],
['Music Performances'],
['Dance'],
['Music Performances'],
['Theater'],
['Musicals'],
['Music Performances'],
['Music Performances'],
['Traditional Art'],
['Music Performances'],
['Musicals'],
['Music Performances'],
['Dance'],
['Theater'],
['Music Performances'],
['Music Performances'],
['Music Performances'],
['Theater'],
['Musicals'],
['Music Performances'],
['Dance'],
['Dance'],
['Music Performances'],
['Music Performances'],
['Dance'],
['Dance'],
['Music Performances'],
['Musicals'],
['Music Performances'],
['Music Performances'],
['Dance'],
['Dance'],
['Music Performances'],
['Music Performances'],
['Dance'],
['Musicals'],
['Musicals'],
['Musicals'],
['Musicals'],
['Dance'],
['Dance'],
['Traditional Art'],
['Music Performances'],
['Music Performances'],
['Music Performances'],
['Theater'],
['Music Performances'],
['Music Performances'],
['Music Performances'],
['Dance'],
['Dance'],
['Traditional Art'],
['Music Performances'],
['Musicals'],
['Theater'],
['Music Performances'],
['Theater'],
['Dance'],
['Music Performances'],
['Music Performances'],
['Dance'],
['Dance'],
['Music Performances'],
['Music Performances'],
['Food'],
['Dance'],
['Theater'],
['Music Performances'],
['Musicals'],
['Music Performances'],
['Music Performances'],
['Music Performances'],
['Musicals'],
['Music Performances'],
['Musicals'],
['Music Performances'],
['Music Performances'],
['Theater'],
['Music Performances'],
['Theater'],
['Music Performances'],
['Music Performances'],
['Musicals'],
['Musicals'],
['Dance'],
['Music Performances'],
['Music Performances'],
['Musicals'],
['Theater'],
['Music Performances'],
['Music Performances'],
['Musicals'],
['Theater'],
['Music Performances'],
['Musicals'],
['Musicals'],
['Theater'],
['Theater'],
['Musicals'],
['Musicals'],
['Musicals'],
['Musicals'],
['Musicals'],
['Music Performances'],
['Music Performances'],
['Musicals'],
['Musicals'],
['Theater'],
['Music Performances'],
['Musicals'],
['Theater'],
['Music Performances'],
['Music Performances'],
['Musicals'],
['Musicals'],
['Music Performances'],
['Musicals'],
['Music Performances'],
['Musicals'],
['Musicals'],
['Music Performances'],
['Theater'],
['Musicals'],
['Music Performances'],
['Music Performances'],
['Dance'],
['Music Performances'],
['Dance'],
['Dance'],
['Music Performances'],
['Dance'],
['Dance'],
['Music Performances'],
['Dance'],
['Interdisciplinary Arts'],
['Musicals'],
['Music Performances'],
['Music Performances'],
['Music Performances'],
['Animation'],
['Theater'],
['Music Performances'],
['Music Performances'],
['Musicals'],
['Music Performances'],
['Music Performances'],
['Music Performances']])

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(perform).transform(perform)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#      Animation  Dance   Food  Interdisciplinary Arts  Music Performances  \
# 0        False  False  False                   False                True
# 1        False  False  False                   False                True
# 2        False  False  False                   False                True
# 3        False  False  False                   False                True
# 4        False  False  False                   False               False
# ..         ...    ...    ...                     ...                 ...
# 160      False  False  False                   False                True
# 161      False  False  False                   False               False
# 162      False  False  False                   False                True
# 163      False  False  False                   False                True
# 164      False  False  False                   False                True
#
#      Musicals  Theater  Traditional Art
# 0       False    False            False
# 1       False    False            False
# 2       False    False            False
# 3       False    False            False
# 4        True    False            False
# ..        ...      ...              ...
# 160     False    False            False
# 161      True    False            False
# 162     False    False            False
# 163     False    False            False
# 164     False    False            False
#
# [165 rows x 8 columns]

# %%
from mlxtend.frequent_patterns import fpgrowth

fpgrowth(df, min_support=0.0, use_colnames=True)
# Out:
#     support                  itemsets
# 0  0.454545      (Music Performances)
# 1  0.242424                (Musicals)
# 2  0.109091                 (Theater)
# 3  0.018182  (Interdisciplinary Arts)
# 4  0.145455                   (Dance)
# 5  0.018182         (Traditional Art)
# 6  0.006061                    (Food)
# 7  0.006061               (Animation)

# %%
import csv
with open('exhibit.csv', newline='') as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)
# Out:
# ['ï»¿Sculptures']
# ['Paintings']
# ['Photography']
# ['Art Design']
# ['Art Design']
# ['Photography']
# ['Photography']
# ['Sculptures, Art Design']
# ['Photography']
# ['Photography, Art Design, Architecture']
# ['Crafting']
# ['Paintings, Sculptures, Art Design']
# ['Paintings']
# ['Art Design']
# ['Art Design']
# ['Paintings']
# ['Photography']
# ['Sculptures']
# ['Photography']
# ['Paintings, Art Design, Architecture']
# ['Art Design']
# ['Photography']
# ['Photography']
# ['Art Design']
# ['Photography']
# ['Crafting']
# ['Photography']
# ['Photography']
# ['Art Design']
# ['Paintings']
# ['Architecture']
# ['Photography']
# ['Art Design']
# ['Photography, Art Design']
# ['Sculptures']
# ['Photography']
# ['Paintings, Photography']
# ['Photography, Art Design']
# ['Photography']
# ['Paintings, Sculptures, Photography, Art Design, Architecture']
# ['Paintings, Photography']
# ['Paintings, Photography']
# ['Art Design, Architecture']
# ['Architecture']
# ['Paintings, Sculptures, Photography, Art Design, Crafting, Architecture']
# ['Art Design']
# ['Art Design']
# ['Architecture']
# ['Photography']
# ['Paintings, Sculptures, Photography, Art Design, Crafting, Architecture']
# ['Paintings, Art Design']
# ['Paintings']
# ['Sculptures']
# ['Art Design']
# ['Paintings']
# ['Crafting']
# ['Paintings, Art Design']
# ['Paintings']
# ['Crafting']
# ['Art Design, Architecture']
# ['Paintings']
# ['Crafting, Architecture']
# ['Paintings, Sculptures, Photography, Art Design, Crafting, Architecture']
# ['Photography']
# ['Paintings']
# ['Architecture']
# ['Art Design']
# ['Photography, Crafting, Architecture']
# ['Photography']
# ['Art Design']
# ['Photography']
# ['Architecture']
# ['Architecture']
# ['Paintings']
# ['Paintings, Sculptures, Photography, Art Design, Crafting, Architecture']
# ['Architecture']
# ['Paintings, Art Design, Crafting']
# ['Photography, Crafting, Architecture']
# ['Photography']
# ['Architecture']
# ['Architecture']
# ['Food']
# ['Architecture']
# ['Paintings']
# ['Paintings']
# ['Art Design']
# ['Architecture']
# ['Photography']
# ['Architecture']
# ['Sculptures']
# ['Art Design']
# ['Photography']
# ['Crafting']
# ['Photography']
# ['Paintings']
# ['Photography']
# ['Paintings']
# ['Photography']
# ['Art Design']
# ['Photography']
# ['Photography']
# ['Architecture']
# ['Architecture']
# ['Crafting']
# ['Photography']
# ['Crafting']
# ['Art Design']
# ['Paintings']
# ['Paintings']
# ['Architecture']
# ['Crafting']
# ['Crafting']
# ['Photography']
# ['Architecture']
# ['Photography']
# ['Art Design']
# ['Paintings']
# ['Crafting']
# ['Photography']
# ['Photography']
# ['Architecture']
# ['Art Design']
# ['Paintings']
# ['Paintings']
# ['Paintings']
# ['Crafting']
# ['Art Design']
# ['Photography']
# ['Art Design']
# ['Art Design']
# ['Art Design']
# ['Paintings']
# ['Photography']
# ['Photography']
# ['Art Design']
# ['Sculptures']
# ['Paintings']
# ['Paintings']
# ['Photography']
# ['Photography']
# ['Photography']
# ['Paintings']
# ['Crafting']
# ['Paintings']
# ['Sculptures']
# ['Paintings']
# ['Paintings']
# ['Photography']
# ['Photography']
# ['Photography']
# ['Sculptures']
# ['Photography']
# ['Architecture']
# ['Art Design']
# ['Sculptures']
# ['Art Design']
# ['Art Design']
# ['Photography']
# ['Paintings']
# ['Paintings']
# ['Art Design']
# ['Paintings']
# ['Photography']

# %%
exhibit=([['Sculptures'],
['Paintings'],
['Photography'],
['Art Design'],
['Art Design'],
['Photography'],
['Photography'],
['Sculptures', 'Art Design'],
['Photography'],
['Photography', 'Art Design', 'Architecture'],
['Crafting'],
['Paintings', 'Sculptures', 'Art Design'],
['Paintings'],
['Art Design'],
['Art Design'],
['Paintings'],
['Photography'],
['Sculptures'],
['Photography'],
['Paintings', 'Art Design', 'Architecture'],
['Art Design'],
['Photography'],
['Photography'],
['Art Design'],
['Photography'],
['Crafting'],
['Photography'],
['Photography'],
['Art Design'],
['Paintings'],
['Architecture'],
['Photography'],
['Art Design'],
['Photography', 'Art Design'],
['Sculptures'],
['Photography'],
['Paintings', 'Photography'],
['Photography, Art Design'],
['Photography'],
['Paintings', 'Sculptures', 'Photography', 'Art Design', 'Architecture'],
['Paintings', 'Photography'],
['Paintings', 'Photography'],
['Art Design', 'Architecture'],
['Architecture'],
['Paintings', 'Sculptures', 'Photography', 'Art Design', 'Crafting', 'Architecture'],
['Art Design'],
['Art Design'],
['Architecture'],
['Photography'],
['Paintings', 'Sculptures', 'Photography', 'Art Design', 'Crafting', 'Architecture'],
['Paintings', 'Art Design'],
['Paintings'],
['Sculptures'],
['Art Design'],
['Paintings'],
['Crafting'],
['Paintings', 'Art Design'],
['Paintings'],
['Crafting'],
['Art Design', 'Architecture'],
['Paintings'],
['Crafting', 'Architecture'],
['Paintings', 'Sculptures', 'Photography', 'Art Design', 'Crafting', 'Architecture'],
['Photography'],
['Paintings'],
['Architecture'],
['Art Design'],
['Photography', 'Crafting', 'Architecture'],
['Photography'],
['Art Design'],
['Photography'],
['Architecture'],
['Architecture'],
['Paintings'],
['Paintings', 'Sculptures', 'Photography', 'Art Design', 'Crafting', 'Architecture'],
['Architecture'],
['Paintings', 'Art Design', 'Crafting'],
['Photography', 'Crafting', 'Architecture'],
['Photography'],
['Architecture'],
['Architecture'],
['Food'],
['Architecture'],
['Paintings'],
['Paintings'],
['Art Design'],
['Architecture'],
['Photography'],
['Architecture'],
['Sculptures'],
['Art Design'],
['Photography'],
['Crafting'],
['Photography'],
['Paintings'],
['Photography'],
['Paintings'],
['Photography'],
['Art Design'],
['Photography'],
['Photography'],
['Architecture'],
['Architecture'],
['Crafting'],
['Photography'],
['Crafting'],
['Art Design'],
['Paintings'],
['Paintings'],
['Architecture'],
['Crafting'],
['Crafting'],
['Photography'],
['Architecture'],
['Photography'],
['Art Design'],
['Paintings'],
['Crafting'],
['Photography'],
['Photography'],
['Architecture'],
['Art Design'],
['Paintings'],
['Paintings'],
['Paintings'],
['Crafting'],
['Art Design'],
['Photography'],
['Art Design'],
['Art Design'],
['Art Design'],
['Paintings'],
['Photography'],
['Photography'],
['Art Design'],
['Sculptures'],
['Paintings'],
['Paintings'],
['Photography'],
['Photography'],
['Photography'],
['Paintings'],
['Crafting'],
['Paintings'],
['Sculptures'],
['Paintings'],
['Paintings'],
['Photography'],
['Photography'],
['Photography'],
['Sculptures'],
['Photography'],
['Architecture'],
['Art Design'],
['Sculptures'],
['Art Design'],
['Art Design'],
['Photography'],
['Paintings'],
['Paintings'],
['Art Design'],
['Paintings'],
['Photography']])

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(exhibit).transform(exhibit)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#      Architecture  Art Design  Crafting   Food  Paintings  Photography  \
# 0           False       False     False  False      False        False
# 1           False       False     False  False       True        False
# 2           False       False     False  False      False         True
# 3           False        True     False  False      False        False
# 4           False        True     False  False      False        False
# ..            ...         ...       ...    ...        ...          ...
# 158         False       False     False  False       True        False
# 159         False       False     False  False       True        False
# 160         False        True     False  False      False        False
# 161         False       False     False  False       True        False
# 162         False       False     False  False      False         True
#
#      Photography, Art Design  Sculptures
# 0                      False        True
# 1                      False       False
# 2                      False       False
# 3                      False       False
# 4                      False       False
# ..                       ...         ...
# 158                    False       False
# 159                    False       False
# 160                    False       False
# 161                    False       False
# 162                    False       False
#
# [163 rows x 8 columns]

# %%
from mlxtend.frequent_patterns import fpgrowth

fpgrowth(df, min_support=0.05, use_colnames=True)
# Out:
#     support                    itemsets
# 0  0.098160                (Sculptures)
# 1  0.263804                 (Paintings)
# 2  0.337423               (Photography)
# 3  0.263804                (Art Design)
# 4  0.184049              (Architecture)
# 5  0.122699                  (Crafting)
# 6  0.061350     (Paintings, Art Design)
# 7  0.055215  (Architecture, Art Design)
