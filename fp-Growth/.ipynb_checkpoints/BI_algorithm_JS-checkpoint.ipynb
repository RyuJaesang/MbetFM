# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

#Data 불러오기
roughResult = pd.read_csv('BI_data_new.csv')
tempFashionResult = roughResult.iloc[:,[1,2]]

roughResult
# Out:
#                         타임스탬프  \
# 0      2019. 11. 7 오후 6:03:37
# 1      2019. 11. 7 오후 6:04:10
# 2      2019. 11. 7 오후 6:10:23
# 3      2019. 11. 7 오후 6:10:27
# 4      2019. 11. 7 오후 6:10:44
# ..                        ...
# 167   2019. 11. 20 오후 2:47:56
# 168   2019. 11. 21 오후 2:58:57
# 169  2019. 11. 21 오후 10:38:54
# 170  2019. 11. 22 오전 11:35:19
# 171   2019. 11. 26 오후 5:22:41
#
#     What genre of music do you most likely to listen to?(Select 3 )  \
# 0                    Pop (팝), Ballad (발라드), Dance (댄스)
# 1    Rap/ Hip Hop (랩/힙합), R&B / Soul (R&B/소울), Rock...
# 2           Pop (팝), Ballad (발라드), R&B / Soul (R&B/소울)
# 3             Pop (팝), Rap/ Hip Hop (랩/힙합), Indie (인디)
# 4                 Idol (아이돌), Ballad (발라드), Dance (댄스)
# ..                                                 ...
# 167         Pop (팝), Ballad (발라드), R&B / Soul (R&B/소울)
# 168  Pop (팝), R&B / Soul (R&B/소울), Rock / Metal (락/메탈)
# 169  Ballad (발라드), Rap/ Hip Hop (랩/힙합), R&B / Soul ...
# 170  Pop (팝), R&B / Soul (R&B/소울), Rock / Metal (락/메탈)
# 171      Idol (아이돌), Ballad (발라드), Rock / Metal (락/메탈)
#
#     What kind of fashion style do you like the most? / 가장 좋아하는 패션 스타일은 무엇입니까? (Select 3 / 3가지 선택)  \
# 0    Workwear (워크웨어륵) (constructed of sturdy fabric...
# 1    Casual (캐주얼룩), Workwear (워크웨어륵) (constructed o...
# 2    Casual (캐주얼룩), Workwear (워크웨어륵) (constructed o...
# 3    Casual (캐주얼룩), Workwear (워크웨어륵) (constructed o...
# 4    Casual (캐주얼룩), Workwear (워크웨어륵) (constructed o...
# ..                                                 ...
# 167  Casual (캐주얼룩), Workwear (워크웨어륵) (constructed o...
# 168  Casual (캐주얼룩), Workwear (워크웨어륵) (constructed o...
# 169          Casual (캐주얼룩), Street (스트릿룩), Dandy (댄디룩)
# 170  Casual (캐주얼룩), Workwear (워크웨어륵) (constructed o...
# 171  Casual (캐주얼룩), Workwear (워크웨어륵) (constructed o...
#
#     What kind of art performances do you like the most? / 가장 좋아하는 공연은 무엇입니까?  \
# 0                              Music Performances (음악)
# 1                              Music Performances (음악)
# 2                              Music Performances (음악)
# 3                              Music Performances (음악)
# 4                                       Musicals (뮤지컬)
# ..                                                 ...
# 167                                       Theater (연극)
# 168                                     Musicals (뮤지컬)
# 169                                       Theater (연극)
# 170                                       Theater (연극)
# 171                            Music Performances (음악)
#
#     What kind of art exhibitions do you like the most? / 가장 좋아하는 전시회는 무엇입니까?
# 0                                      Sculptures (조각)
# 1                                       Paintings (회화)
# 2                                     Photography (사진)
# 3                                     Art Design (디자인)
# 4                                     Art Design (디자인)
# ..                                                 ...
# 167                                   Art Design (디자인)
# 168                                   Art Design (디자인)
# 169                                   Photography (사진)
# 170                                     Paintings (회화)
# 171                                      Crafting (공예)
#
# [172 rows x 5 columns]

# %%
#MusicData 정제
result3 = []
for i in range(len(tempFashionResult)):
    result1 = tempFashionResult.iloc[i, 0].split(',')
    for j in range(len(result1)):
        result2 = result1[j].split('(')
        for k in result2:
            if k != " " and k[-1] != ")" and k !=' Instrumental':
                result3.append(k.replace(" ", ""))

                
resultMusic = [["" for col in range(3)] for row in range(172)]
for i in range(len(result3)):
    row = int(i/3)
    col = i%3
    resultMusic[row][col] = result3[i]

result1
# Out:
# ['Idol (아이돌)', ' Ballad (발라드)', ' Rock / Metal (락/메탈)']

# %%
tempFashionResult
# Out:
#     What genre of music do you most likely to listen to?(Select 3 )  \
# 0                    Pop (팝), Ballad (발라드), Dance (댄스)
# 1    Rap/ Hip Hop (랩/힙합), R&B / Soul (R&B/소울), Rock...
# 2           Pop (팝), Ballad (발라드), R&B / Soul (R&B/소울)
# 3             Pop (팝), Rap/ Hip Hop (랩/힙합), Indie (인디)
# 4                 Idol (아이돌), Ballad (발라드), Dance (댄스)
# ..                                                 ...
# 167         Pop (팝), Ballad (발라드), R&B / Soul (R&B/소울)
# 168  Pop (팝), R&B / Soul (R&B/소울), Rock / Metal (락/메탈)
# 169  Ballad (발라드), Rap/ Hip Hop (랩/힙합), R&B / Soul ...
# 170  Pop (팝), R&B / Soul (R&B/소울), Rock / Metal (락/메탈)
# 171      Idol (아이돌), Ballad (발라드), Rock / Metal (락/메탈)
#
#     What kind of fashion style do you like the most? / 가장 좋아하는 패션 스타일은 무엇입니까? (Select 3 / 3가지 선택)
# 0    Workwear (워크웨어륵) (constructed of sturdy fabric...
# 1    Casual (캐주얼룩), Workwear (워크웨어륵) (constructed o...
# 2    Casual (캐주얼룩), Workwear (워크웨어륵) (constructed o...
# 3    Casual (캐주얼룩), Workwear (워크웨어륵) (constructed o...
# 4    Casual (캐주얼룩), Workwear (워크웨어륵) (constructed o...
# ..                                                 ...
# 167  Casual (캐주얼룩), Workwear (워크웨어륵) (constructed o...
# 168  Casual (캐주얼룩), Workwear (워크웨어륵) (constructed o...
# 169          Casual (캐주얼룩), Street (스트릿룩), Dandy (댄디룩)
# 170  Casual (캐주얼룩), Workwear (워크웨어륵) (constructed o...
# 171  Casual (캐주얼룩), Workwear (워크웨어륵) (constructed o...
#
# [172 rows x 2 columns]

# %%
#FashionData 정제
resultF = []
resultF1 = []
resultF4 = []
for i in range(len(tempFashionResult)):
    resultF1.append(tempFashionResult.iloc[i, 1])

for i in range(len(resultF1)):
    resultF1[i] = resultF1[i].replace("Workwear (워크웨어륵) (constructed of sturdy fabrics like denim and corduroy, and it has an oversized fit to allow for movement)", "Workwear")

for i in range(len(resultF1)):
    resultF2 = resultF1[i].split(',')
    for j in range(len(resultF2)):
        resultF3 = resultF2[j].split('(')
        for k in resultF3:
            if k != " " and k[-1] != ")" and k !=' Instrumental':
                resultF4.append(k.replace(" ", ""))
            
resultFashion = [["" for col in range(3)] for row in range(172)]
for i in range(len(resultF4)):
    row = int(i/3)
    col = i%3
    resultFashion[row][col] = resultF4[i]

resultFashion
# Out:
# [['Workwear', 'Techwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Street', 'Goth', 'Dandy'],
#  ['Casual', 'Street', 'Vintage'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Workwear', 'Street', 'Dandy'],
#  ['Casual', 'Street', 'Dandy'],
#  ['Casual', 'Grunge', 'Dandy'],
#  ['Casual', 'Workwear', 'Techwear'],
#  ['Street', 'Grunge', 'Techwear'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Street', 'Vintage', 'Techwear'],
#  ['Street', 'Grunge', 'Techwear'],
#  ['Goth', 'Techwear', '씹덕의상'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Casual', 'Street', 'Dandy'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Street', 'Grunge'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Grunge'],
#  ['Workwear', 'Street', 'Techwear'],
#  ['Casual', 'Street', 'Techwear'],
#  ['Casual', 'Street', 'Chic'],
#  ['Workwear', 'Preppy', 'Dandy'],
#  ['Casual', 'Vintage', 'Chic'],
#  ['Workwear', 'Street', 'Chic'],
#  ['Workwear', 'Chic', 'Grunge'],
#  ['Casual', 'Bohemian', 'Dandy'],
#  ['Casual', 'Workwear', 'Athleisure'],
#  ['Casual', 'Grunge', 'Dandy'],
#  ['Casual', 'Techwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Casual', 'Athleisure', 'Chic'],
#  ['Street', 'Chic', 'Bohemian'],
#  ['Street', 'Grunge', 'Techwear'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Casual', 'Workwear', 'Vintage'],
#  ['Athleisure', 'Street', 'Grunge'],
#  ['Casual', 'Workwear', 'Preppy'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Workwear', 'Athleisure'],
#  ['Casual', 'Chic', 'Preppy'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Street', 'Grunge'],
#  ['Casual', 'Street', 'Vintage'],
#  ['Casual', 'Chic', 'Bohemian'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Vintage'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Casual', 'Athleisure', 'Vintage'],
#  ['Casual', 'Vintage', 'Dandy'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Street', 'Vintage', 'Chic'],
#  ['Street', 'Vintage', 'Chic'],
#  ['Casual', 'Workwear', 'Goth'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Street', 'Chic'],
#  ['Street', 'Vintage', 'Chic'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Athleisure', 'Preppy', 'Bohemian'],
#  ['Workwear', 'Vintage', 'Bohemian'],
#  ['Casual', 'Street', 'Preppy'],
#  ['Casual', 'Workwear', 'Vintage'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Workwear', 'Techwear', 'Dandy'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Street', 'Preppy'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Chic', 'Preppy', 'Bohemian'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Chic', 'Grunge'],
#  ['Street', 'Vintage', 'Bohemian'],
#  ['Casual', 'Vintage', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Athleisure', 'Chic'],
#  ['Workwear', 'Athleisure', 'Street'],
#  ['Vintage', 'Chic', 'seethroughloom'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Vintage', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Workwear', 'Street', 'Techwear'],
#  ['Workwear', 'Techwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Casual', 'Chic', 'Dandy'],
#  ['Casual', 'Workwear', 'Grunge'],
#  ['Casual', 'Vintage', 'Chic'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Workwear', 'Bohemian'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Casual', 'Street', 'Dandy'],
#  ['Casual', 'Vintage', 'Preppy'],
#  ['Casual', 'Bohemian', 'Dandy'],
#  ['Street', 'Chic', 'Bohemian'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Workwear', 'Techwear', '편하고계절에맞는옷'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Workwear', 'Chic', 'Preppy'],
#  ['Casual', 'Preppy', 'Grunge'],
#  ['Vintage', 'Chic', 'Bohemian'],
#  ['Casual', 'Street', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Street', 'Grunge', '미니멀'],
#  ['Casual', 'Workwear', 'Vintage'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Chic', 'Preppy', 'Grunge'],
#  ['Casual', 'Street', 'Chic'],
#  ['Vintage', 'Techwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Workwear', 'Chic', 'Grunge'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Workwear', 'Vintage'],
#  ['Street', 'Vintage', 'Grunge'],
#  ['Street', 'Chic', 'Grunge'],
#  ['Street', 'Vintage', 'Chic'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Casual', 'Chic', 'Preppy'],
#  ['Street', 'Chic', 'Bohemian'],
#  ['Workwear', 'Athleisure', 'Street'],
#  ['Casual', 'Workwear', 'Athleisure'],
#  ['Casual', 'Street', 'Grunge'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Casual', 'Vintage', 'Preppy'],
#  ['Athleisure', 'Street', 'Dandy'],
#  ['Street', 'Chic', 'Techwear'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Casual', 'Street', 'Grunge'],
#  ['Workwear', 'Chic', 'Preppy'],
#  ['Street', 'Chic', 'Grunge'],
#  ['Workwear', 'Street', 'Chic'],
#  ['Casual', 'Street', 'Grunge'],
#  ['Street', 'Vintage', 'Chic'],
#  ['Workwear', 'Athleisure', 'Chic'],
#  ['Casual', 'Street', 'Grunge'],
#  ['Casual', 'Workwear', 'Grunge'],
#  ['Workwear', 'Street', 'Chic'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Casual', 'Street', 'Dandy'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Casual', 'Workwear', 'Street']]

# %%
#popMusic table
popMusic = []
for i in range(len(resultMusic)):
    if 'Pop' in resultMusic[i]:
        popMusic.append(resultFashion[i])
popMusic
# Out:
# [['Workwear', 'Techwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Street', 'Vintage'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Workwear', 'Street', 'Dandy'],
#  ['Casual', 'Street', 'Dandy'],
#  ['Casual', 'Grunge', 'Dandy'],
#  ['Casual', 'Workwear', 'Techwear'],
#  ['Goth', 'Techwear', '씹덕의상'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Grunge'],
#  ['Casual', 'Street', 'Techwear'],
#  ['Workwear', 'Chic', 'Grunge'],
#  ['Casual', 'Workwear', 'Athleisure'],
#  ['Casual', 'Grunge', 'Dandy'],
#  ['Casual', 'Techwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Casual', 'Athleisure', 'Chic'],
#  ['Street', 'Chic', 'Bohemian'],
#  ['Street', 'Grunge', 'Techwear'],
#  ['Casual', 'Workwear', 'Vintage'],
#  ['Athleisure', 'Street', 'Grunge'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Workwear', 'Athleisure'],
#  ['Casual', 'Chic', 'Preppy'],
#  ['Casual', 'Street', 'Grunge'],
#  ['Casual', 'Street', 'Vintage'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Vintage'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Casual', 'Vintage', 'Dandy'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Street', 'Vintage', 'Chic'],
#  ['Casual', 'Workwear', 'Goth'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Street', 'Chic'],
#  ['Athleisure', 'Preppy', 'Bohemian'],
#  ['Workwear', 'Vintage', 'Bohemian'],
#  ['Casual', 'Street', 'Preppy'],
#  ['Casual', 'Workwear', 'Vintage'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Workwear', 'Techwear', 'Dandy'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Street', 'Preppy'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Chic', 'Preppy', 'Bohemian'],
#  ['Casual', 'Chic', 'Grunge'],
#  ['Street', 'Vintage', 'Bohemian'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Athleisure', 'Chic'],
#  ['Workwear', 'Athleisure', 'Street'],
#  ['Vintage', 'Chic', 'seethroughloom'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Street', 'Chic'],
#  ['Workwear', 'Techwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Casual', 'Chic', 'Dandy'],
#  ['Casual', 'Vintage', 'Chic'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Casual', 'Street', 'Dandy'],
#  ['Casual', 'Vintage', 'Preppy'],
#  ['Casual', 'Bohemian', 'Dandy'],
#  ['Street', 'Chic', 'Bohemian'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Workwear', 'Techwear', '편하고계절에맞는옷'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Workwear', 'Chic', 'Preppy'],
#  ['Casual', 'Preppy', 'Grunge'],
#  ['Vintage', 'Chic', 'Bohemian'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Street', 'Grunge', '미니멀'],
#  ['Casual', 'Workwear', 'Vintage'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Casual', 'Street', 'Chic'],
#  ['Vintage', 'Techwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Workwear', 'Vintage'],
#  ['Street', 'Vintage', 'Grunge'],
#  ['Street', 'Chic', 'Grunge'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Casual', 'Chic', 'Preppy'],
#  ['Street', 'Chic', 'Bohemian'],
#  ['Workwear', 'Athleisure', 'Street'],
#  ['Casual', 'Workwear', 'Athleisure'],
#  ['Casual', 'Street', 'Grunge'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Casual', 'Vintage', 'Preppy'],
#  ['Street', 'Chic', 'Techwear'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Casual', 'Street', 'Grunge'],
#  ['Workwear', 'Chic', 'Preppy'],
#  ['Workwear', 'Street', 'Chic'],
#  ['Casual', 'Street', 'Grunge'],
#  ['Street', 'Vintage', 'Chic'],
#  ['Workwear', 'Athleisure', 'Chic'],
#  ['Casual', 'Street', 'Grunge'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Casual', 'Workwear', 'Chic']]

# %%
#idolMusic table
idolMusic = []
for i in range(len(resultMusic)):
    if 'Idol' in resultMusic[i]:
        idolMusic.append(resultFashion[i])
idolMusic
# Out:
# [['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Street', 'Vintage'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Vintage', 'Chic'],
#  ['Casual', 'Bohemian', 'Dandy'],
#  ['Casual', 'Workwear', 'Athleisure'],
#  ['Casual', 'Grunge', 'Dandy'],
#  ['Casual', 'Athleisure', 'Chic'],
#  ['Street', 'Chic', 'Bohemian'],
#  ['Street', 'Grunge', 'Techwear'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Casual', 'Workwear', 'Preppy'],
#  ['Casual', 'Workwear', 'Athleisure'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Chic', 'Bohemian'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Athleisure', 'Vintage'],
#  ['Street', 'Vintage', 'Chic'],
#  ['Casual', 'Street', 'Chic'],
#  ['Street', 'Vintage', 'Chic'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Street', 'Preppy'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Chic', 'Preppy', 'Bohemian'],
#  ['Casual', 'Vintage', 'Dandy'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Vintage', 'Chic', 'seethroughloom'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Grunge'],
#  ['Casual', 'Vintage', 'Chic'],
#  ['Casual', 'Workwear', 'Bohemian'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Casual', 'Vintage', 'Preppy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Vintage', 'Chic', 'Bohemian'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Vintage'],
#  ['Casual', 'Street', 'Chic'],
#  ['Chic', 'Preppy', 'Grunge'],
#  ['Vintage', 'Techwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Workwear', 'Vintage'],
#  ['Street', 'Vintage', 'Grunge'],
#  ['Casual', 'Chic', 'Preppy'],
#  ['Street', 'Chic', 'Bohemian'],
#  ['Casual', 'Street', 'Grunge'],
#  ['Athleisure', 'Street', 'Dandy'],
#  ['Street', 'Chic', 'Grunge'],
#  ['Workwear', 'Athleisure', 'Chic'],
#  ['Casual', 'Workwear', 'Grunge'],
#  ['Casual', 'Workwear', 'Street']]

# %%
#BalladMusic table
balladMusic = []
for i in range(len(resultMusic)):
    if 'Ballad' in resultMusic[i]:
        balladMusic.append(resultFashion[i])
balladMusic
# Out:
# [['Workwear', 'Techwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Street', 'Vintage'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Grunge', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Street', 'Grunge', 'Techwear'],
#  ['Goth', 'Techwear', '씹덕의상'],
#  ['Casual', 'Street', 'Dandy'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Street', 'Grunge'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Vintage', 'Chic'],
#  ['Workwear', 'Chic', 'Grunge'],
#  ['Casual', 'Techwear', 'Dandy'],
#  ['Casual', 'Athleisure', 'Chic'],
#  ['Street', 'Grunge', 'Techwear'],
#  ['Athleisure', 'Street', 'Grunge'],
#  ['Casual', 'Workwear', 'Preppy'],
#  ['Casual', 'Workwear', 'Athleisure'],
#  ['Casual', 'Chic', 'Preppy'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Street', 'Vintage'],
#  ['Casual', 'Chic', 'Bohemian'],
#  ['Casual', 'Workwear', 'Vintage'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Vintage', 'Dandy'],
#  ['Street', 'Vintage', 'Chic'],
#  ['Casual', 'Workwear', 'Goth'],
#  ['Casual', 'Street', 'Chic'],
#  ['Street', 'Vintage', 'Chic'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Workwear', 'Vintage', 'Bohemian'],
#  ['Casual', 'Workwear', 'Vintage'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Chic', 'Preppy', 'Bohemian'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Chic', 'Grunge'],
#  ['Street', 'Vintage', 'Bohemian'],
#  ['Casual', 'Vintage', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Athleisure', 'Chic'],
#  ['Vintage', 'Chic', 'seethroughloom'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Vintage', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Grunge'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Street', 'Chic'],
#  ['Workwear', 'Chic', 'Preppy'],
#  ['Casual', 'Preppy', 'Grunge'],
#  ['Casual', 'Street', 'Dandy'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Chic', 'Preppy', 'Grunge'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Casual', 'Workwear', 'Athleisure'],
#  ['Casual', 'Street', 'Grunge'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Street', 'Dandy'],
#  ['Casual', 'Workwear', 'Street']]

# %%
#DanceMusic table
danceMusic = []
for i in range(len(resultMusic)):
    if 'Dance' in resultMusic[i]:
        danceMusic.append(resultFashion[i])
danceMusic
# Out:
# [['Workwear', 'Techwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Workwear', 'Street', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Street', 'Chic'],
#  ['Workwear', 'Street', 'Techwear'],
#  ['Casual', 'Bohemian', 'Dandy'],
#  ['Casual', 'Workwear', 'Athleisure'],
#  ['Street', 'Chic', 'Bohemian'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Street', 'Grunge'],
#  ['Casual', 'Chic', 'Bohemian'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Vintage'],
#  ['Casual', 'Athleisure', 'Vintage'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Street', 'Vintage', 'Chic'],
#  ['Street', 'Vintage', 'Chic'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Athleisure', 'Preppy', 'Bohemian'],
#  ['Casual', 'Street', 'Preppy'],
#  ['Casual', 'Workwear', 'Vintage'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Chic', 'Grunge'],
#  ['Casual', 'Vintage', 'Dandy'],
#  ['Casual', 'Athleisure', 'Chic'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Vintage', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Workwear', 'Street', 'Techwear'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Casual', 'Vintage', 'Chic'],
#  ['Casual', 'Workwear', 'Bohemian'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Casual', 'Vintage', 'Preppy'],
#  ['Street', 'Chic', 'Bohemian'],
#  ['Casual', 'Street', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Workwear', 'Vintage'],
#  ['Street', 'Vintage', 'Chic'],
#  ['Casual', 'Chic', 'Preppy'],
#  ['Casual', 'Vintage', 'Preppy'],
#  ['Street', 'Chic', 'Techwear'],
#  ['Casual', 'Workwear', 'Grunge'],
#  ['Workwear', 'Street', 'Chic']]

# %%
#Rap/Hiphop Music table
rap_hiphopMusic = []
for i in range(len(resultMusic)):
    if 'Rap/HipHop' in resultMusic[i]:
        rap_hiphopMusic.append(resultFashion[i])
rap_hiphopMusic
# Out:
# [['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Street', 'Goth', 'Dandy'],
#  ['Casual', 'Street', 'Dandy'],
#  ['Casual', 'Grunge', 'Dandy'],
#  ['Street', 'Grunge', 'Techwear'],
#  ['Street', 'Vintage', 'Techwear'],
#  ['Street', 'Grunge', 'Techwear'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Casual', 'Street', 'Dandy'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Street', 'Grunge'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Workwear', 'Street', 'Techwear'],
#  ['Casual', 'Street', 'Techwear'],
#  ['Workwear', 'Preppy', 'Dandy'],
#  ['Workwear', 'Street', 'Chic'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Casual', 'Workwear', 'Preppy'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Street', 'Vintage', 'Chic'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Workwear', 'Techwear', 'Dandy'],
#  ['Casual', 'Street', 'Preppy'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Vintage', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Street', 'Chic'],
#  ['Workwear', 'Street', 'Techwear'],
#  ['Casual', 'Chic', 'Dandy'],
#  ['Casual', 'Street', 'Dandy'],
#  ['Casual', 'Bohemian', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Street', 'Grunge', '미니멀'],
#  ['Casual', 'Workwear', 'Vintage'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Street', 'Chic'],
#  ['Workwear', 'Chic', 'Grunge'],
#  ['Street', 'Chic', 'Grunge'],
#  ['Street', 'Vintage', 'Chic'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Casual', 'Workwear', 'Athleisure'],
#  ['Athleisure', 'Street', 'Dandy'],
#  ['Workwear', 'Street', 'Chic'],
#  ['Casual', 'Street', 'Grunge'],
#  ['Workwear', 'Street', 'Chic'],
#  ['Casual', 'Street', 'Dandy']]

# %%
#R&B/Soul Music table
rb_soulMusic = []
for i in range(len(resultMusic)):
    if 'R&B/Soul' in resultMusic[i]:
        rb_soulMusic.append(resultFashion[i])
rb_soulMusic
# Out:
# [['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Street', 'Goth', 'Dandy'],
#  ['Casual', 'Street', 'Dandy'],
#  ['Street', 'Grunge', 'Techwear'],
#  ['Street', 'Grunge', 'Techwear'],
#  ['Casual', 'Street', 'Dandy'],
#  ['Casual', 'Street', 'Grunge'],
#  ['Casual', 'Workwear', 'Grunge'],
#  ['Workwear', 'Preppy', 'Dandy'],
#  ['Workwear', 'Street', 'Chic'],
#  ['Workwear', 'Chic', 'Grunge'],
#  ['Casual', 'Bohemian', 'Dandy'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Casual', 'Workwear', 'Vintage'],
#  ['Athleisure', 'Street', 'Grunge'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Street', 'Vintage'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Casual', 'Vintage', 'Dandy'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Casual', 'Workwear', 'Goth'],
#  ['Casual', 'Street', 'Chic'],
#  ['Athleisure', 'Preppy', 'Bohemian'],
#  ['Workwear', 'Vintage', 'Bohemian'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Workwear', 'Street', 'Techwear'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Chic', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Workwear', 'Bohemian'],
#  ['Casual', 'Street', 'Dandy'],
#  ['Casual', 'Bohemian', 'Dandy'],
#  ['Workwear', 'Chic', 'Preppy'],
#  ['Casual', 'Street', 'Dandy'],
#  ['Street', 'Grunge', '미니멀'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Workwear', 'Chic', 'Grunge'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Workwear', 'Athleisure', 'Street'],
#  ['Athleisure', 'Street', 'Dandy'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Street', 'Chic', 'Grunge'],
#  ['Casual', 'Street', 'Grunge'],
#  ['Street', 'Vintage', 'Chic'],
#  ['Workwear', 'Athleisure', 'Chic'],
#  ['Casual', 'Street', 'Grunge'],
#  ['Workwear', 'Street', 'Chic'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Casual', 'Street', 'Dandy'],
#  ['Casual', 'Workwear', 'Chic']]

# %%
#Indie Music table
indieMusic = []
for i in range(len(resultMusic)):
    if 'Indie' in resultMusic[i]:
        indieMusic.append(resultFashion[i])
indieMusic
# Out:
# [['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Techwear'],
#  ['Street', 'Grunge', 'Techwear'],
#  ['Street', 'Vintage', 'Techwear'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Street', 'Chic'],
#  ['Workwear', 'Preppy', 'Dandy'],
#  ['Casual', 'Vintage', 'Chic'],
#  ['Workwear', 'Street', 'Chic'],
#  ['Casual', 'Techwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Vintage'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Street', 'Vintage', 'Chic'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Workwear', 'Techwear', 'Dandy'],
#  ['Street', 'Vintage', 'Bohemian'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Workwear', 'Techwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Casual', 'Workwear', 'Grunge'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Preppy', 'Grunge'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Chic', 'Preppy', 'Grunge'],
#  ['Workwear', 'Chic', 'Grunge'],
#  ['Casual', 'Street', 'Chic'],
#  ['Street', 'Chic', 'Grunge'],
#  ['Street', 'Vintage', 'Chic'],
#  ['Street', 'Chic', 'Bohemian'],
#  ['Workwear', 'Athleisure', 'Street'],
#  ['Casual', 'Street', 'Grunge'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Street', 'Chic', 'Techwear'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Casual', 'Street', 'Grunge'],
#  ['Workwear', 'Chic', 'Preppy'],
#  ['Street', 'Chic', 'Grunge'],
#  ['Street', 'Vintage', 'Chic'],
#  ['Casual', 'Workwear', 'Grunge']]

# %%
#Rock/Metal Music table
rock_metalMusic = []
for i in range(len(resultMusic)):
    if 'Rock/Metal' in resultMusic[i]:
        rock_metalMusic.append(resultFashion[i])
rock_metalMusic

#트로트는 그냥 버렸어
# Out:
# [['Casual', 'Workwear', 'Street'],
#  ['Street', 'Goth', 'Dandy'],
#  ['Workwear', 'Street', 'Dandy'],
#  ['Casual', 'Workwear', 'Techwear'],
#  ['Street', 'Vintage', 'Techwear'],
#  ['Casual', 'Athleisure', 'Street'],
#  ['Casual', 'Workwear', 'Grunge'],
#  ['Workwear', 'Street', 'Techwear'],
#  ['Casual', 'Street', 'Techwear'],
#  ['Casual', 'Grunge', 'Dandy'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Casual', 'Street', 'Chic'],
#  ['Casual', 'Athleisure', 'Vintage'],
#  ['Casual', 'Street', 'Preppy'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Workwear', 'Athleisure', 'Street'],
#  ['Casual', 'Workwear', 'Street'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Workwear', 'Techwear', 'Dandy'],
#  ['Street', 'Chic', 'Bohemian'],
#  ['Workwear', 'Techwear', '편하고계절에맞는옷'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Casual', 'Workwear', 'Dandy'],
#  ['Vintage', 'Chic', 'Bohemian'],
#  ['Vintage', 'Techwear', 'Dandy'],
#  ['Street', 'Vintage', 'Grunge'],
#  ['Casual', 'Vintage', 'Preppy'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Casual', 'Workwear', 'Chic'],
#  ['Casual', 'Workwear', 'Street']]

# %%
#popMusic Apriori
te = TransactionEncoder()
te_ary = te.fit(popMusic).transform(popMusic)
concluded = pd.DataFrame(te_ary, columns=te.columns_)
tempApriori = apriori(concluded, min_support=0.3, use_colnames=True)

popApriori = tempApriori.sort_values(["support"], ascending=[False])
popApriori
# Out:
#     support            itemsets
# 0  0.750000            (Casual)
# 3  0.475806          (Workwear)
# 2  0.443548            (Street)
# 5  0.370968  (Workwear, Casual)
# 1  0.346774              (Chic)
# 4  0.314516    (Street, Casual)

# %%
#idolMusic Apriori
te = TransactionEncoder()
te_ary = te.fit(idolMusic).transform(idolMusic)
concluded = pd.DataFrame(te_ary, columns=te.columns_)
tempApriori = apriori(concluded, min_support=0.3, use_colnames=True)

idolApriori = tempApriori.sort_values(["support"], ascending=[False])
idolApriori
# Out:
#     support            itemsets
# 0  0.758621            (Casual)
# 1  0.413793              (Chic)
# 2  0.396552            (Street)
# 3  0.396552          (Workwear)
# 4  0.379310  (Workwear, Casual)

# %%
#balladMusic Apriori
te = TransactionEncoder()
te_ary = te.fit(balladMusic).transform(balladMusic)
concluded = pd.DataFrame(te_ary, columns=te.columns_)
tempApriori = apriori(concluded, min_support=0.3, use_colnames=True)


balladApriori = tempApriori.sort_values(["support"], ascending=[False])
balladApriori
# Out:
#     support            itemsets
# 0  0.813333            (Casual)
# 3  0.493333          (Workwear)
# 5  0.440000  (Workwear, Casual)
# 2  0.373333            (Street)
# 1  0.360000             (Dandy)
# 4  0.346667     (Dandy, Casual)

# %%
#danceMusic Apriori
te = TransactionEncoder()
te_ary = te.fit(danceMusic).transform(danceMusic)
concluded = pd.DataFrame(te_ary, columns=te.columns_)
tempApriori = apriori(concluded, min_support=0.3, use_colnames=True)

danceApriori = tempApriori.sort_values(["support"], ascending=[False])
danceApriori
# Out:
#     support            itemsets
# 0  0.764706            (Casual)
# 3  0.490196          (Workwear)
# 2  0.411765            (Street)
# 4  0.392157  (Workwear, Casual)
# 1  0.333333              (Chic)

# %%
#rap_hiphop Music Apriori
te = TransactionEncoder()
te_ary = te.fit(rap_hiphopMusic).transform(rap_hiphopMusic)
concluded = pd.DataFrame(te_ary, columns=te.columns_)
tempApriori = apriori(concluded, min_support=0.3, use_colnames=True)

rap_hiphopApriori = tempApriori.sort_values(["support"], ascending=[False])
rap_hiphopApriori
# Out:
#     support          itemsets
# 0  0.679245          (Casual)
# 2  0.660377          (Street)
# 3  0.433962        (Workwear)
# 5  0.396226  (Street, Casual)
# 1  0.377358           (Dandy)
# 4  0.301887   (Dandy, Casual)

# %%
#rb_soul Music Apriori
te = TransactionEncoder()
te_ary = te.fit(rb_soulMusic).transform(rb_soulMusic)
concluded = pd.DataFrame(te_ary, columns=te.columns_)
tempApriori = apriori(concluded, min_support=0.3, use_colnames=True)

rb_soulApriori = tempApriori.sort_values(["support"], ascending=[False])
rb_soulApriori
# Out:
#     support            itemsets
# 0  0.716418            (Casual)
# 3  0.552239            (Street)
# 4  0.507463          (Workwear)
# 5  0.373134    (Street, Casual)
# 6  0.358209  (Workwear, Casual)
# 1  0.313433              (Chic)
# 2  0.313433             (Dandy)

# %%
#indie Music Apriori
te = TransactionEncoder()
te_ary = te.fit(indieMusic).transform(indieMusic)
concluded = pd.DataFrame(te_ary, columns=te.columns_)
tempApriori = apriori(concluded, min_support=0.3, use_colnames=True)

indieApriori = tempApriori.sort_values(["support"], ascending=[False])
indieApriori
# Out:
#     support            itemsets
# 0  0.590909            (Casual)
# 2  0.522727            (Street)
# 3  0.522727          (Workwear)
# 1  0.363636              (Chic)
# 4  0.363636  (Workwear, Casual)

# %%
#rock_metal Music Apriori
te = TransactionEncoder()
te_ary = te.fit(rock_metalMusic).transform(rock_metalMusic)
concluded = pd.DataFrame(te_ary, columns=te.columns_)
tempApriori = apriori(concluded, min_support=0.3, use_colnames=True)

rock_metalApriori = tempApriori.sort_values(["support"], ascending=[False])
rock_metalApriori
# Out:
#    support            itemsets
# 0  0.65625            (Casual)
# 2  0.59375          (Workwear)
# 1  0.50000            (Street)
# 3  0.43750  (Workwear, Casual)

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

#Data 불러오기
roughResult = pd.read_csv('BI_data_new.csv')
artPerformanceData = roughResult.iloc[:,[1,3]]
artPerformanceData.head()
# Out:
#   What genre of music do you most likely to listen to?(Select 3 )  \
# 0                  Pop (팝), Ballad (발라드), Dance (댄스)
# 1  Rap/ Hip Hop (랩/힙합), R&B / Soul (R&B/소울), Rock...
# 2         Pop (팝), Ballad (발라드), R&B / Soul (R&B/소울)
# 3           Pop (팝), Rap/ Hip Hop (랩/힙합), Indie (인디)
# 4               Idol (아이돌), Ballad (발라드), Dance (댄스)
#
#   What kind of art performances do you like the most? / 가장 좋아하는 공연은 무엇입니까?
# 0                            Music Performances (음악)
# 1                            Music Performances (음악)
# 2                            Music Performances (음악)
# 3                            Music Performances (음악)
# 4                                     Musicals (뮤지컬)

# %%
#artPerformance 정제
resultPerformance = []
for j in range(len(artPerformanceData)):
    resultP1 = artPerformanceData.iloc[j, 1].split('(')

    resultPerformance.append(resultP1[0].replace(" ", ""))

resultPerformance
# Out:
# ['MusicPerformances',
#  'MusicPerformances',
#  'MusicPerformances',
#  'MusicPerformances',
#  'Musicals',
#  'Musicals',
#  'MusicPerformances',
#  'Musicals',
#  'Musicals',
#  'Musicals',
#  'Theater',
#  'InterdisciplinaryArts',
#  'MusicPerformances',
#  'Musicals',
#  'MusicPerformances',
#  'MusicPerformances',
#  'InterdisciplinaryArts',
#  'MusicPerformances',
#  'MusicPerformances',
#  'MusicPerformances',
#  'Dance',
#  'MusicPerformances',
#  'Theater',
#  'Musicals',
#  'MusicPerformances',
#  'MusicPerformances',
#  'TraditionalArt',
#  'MusicPerformances',
#  'Musicals',
#  'MusicPerformances',
#  'Dance',
#  'Theater',
#  'MusicPerformances',
#  'MusicPerformances',
#  'MusicPerformances',
#  'Theater',
#  'Musicals',
#  'MusicPerformances',
#  'Dance',
#  'Dance',
#  'MusicPerformances',
#  'MusicPerformances',
#  'Dance',
#  'Dance',
#  'MusicPerformances',
#  'Musicals',
#  'MusicPerformances',
#  'MusicPerformances',
#  'Dance',
#  'Dance',
#  'MusicPerformances',
#  'MusicPerformances',
#  'Dance',
#  'Musicals',
#  'Musicals',
#  'Musicals',
#  'Musicals',
#  'Dance',
#  'Dance',
#  'TraditionalArt',
#  'MusicPerformances',
#  'MusicPerformances',
#  'MusicPerformances',
#  'Theater',
#  'MusicPerformances',
#  'MusicPerformances',
#  'MusicPerformances',
#  'Dance',
#  'Dance',
#  'TraditionalArt',
#  'MusicPerformances',
#  'Musicals',
#  'Theater',
#  'MusicPerformances',
#  'Theater',
#  'Dance',
#  'MusicPerformances',
#  'MusicPerformances',
#  'Dance',
#  'Dance',
#  'MusicPerformances',
#  'MusicPerformances',
#  'Food',
#  'Dance',
#  'Theater',
#  'MusicPerformances',
#  'Musicals',
#  'MusicPerformances',
#  'MusicPerformances',
#  'MusicPerformances',
#  'Musicals',
#  'MusicPerformances',
#  '영화',
#  'Musicals',
#  'MusicPerformances',
#  'MusicPerformances',
#  'Theater',
#  'MusicPerformances',
#  'Theater',
#  'MusicPerformances',
#  'MusicPerformances',
#  'Musicals',
#  'Musicals',
#  'Dance',
#  'MusicPerformances',
#  'MusicPerformances',
#  'Musicals',
#  'Theater',
#  'MusicPerformances',
#  'MusicPerformances',
#  'Musicals',
#  'Theater',
#  'MusicPerformances',
#  'Musicals',
#  'Musicals',
#  'Theater',
#  'Theater',
#  'Musicals',
#  'Musicals',
#  'Musicals',
#  'Musicals',
#  'Musicals',
#  'MusicPerformances',
#  'MusicPerformances',
#  'Musicals',
#  'Musicals',
#  'Theater',
#  'MusicPerformances',
#  'Musicals',
#  'Theater',
#  'MusicPerformances',
#  'MusicPerformances',
#  'Musicals',
#  'Musicals',
#  'MusicPerformances',
#  'Musicals',
#  'MusicPerformances',
#  'Musicals',
#  'Musicals',
#  'MusicPerformances',
#  'Theater',
#  'Musicals',
#  'MusicPerformances',
#  'MusicPerformances',
#  'Dance',
#  'MusicPerformances',
#  'Dance',
#  'Dance',
#  'MusicPerformances',
#  'Dance',
#  'Dance',
#  'MusicPerformances',
#  'Dance',
#  'InterdisciplinaryArts',
#  'Musicals',
#  'MusicPerformances',
#  'MusicPerformances',
#  'MusicPerformances',
#  'Animation',
#  'Theater',
#  'MusicPerformances',
#  'MusicPerformances',
#  'Musicals',
#  'MusicPerformances',
#  'MusicPerformances',
#  'MusicPerformances',
#  'MusicPerformances',
#  'Theater',
#  'Musicals',
#  'Theater',
#  'Theater',
#  'MusicPerformances']

# %%
#Theater table
theater = []
for i in range(len(resultPerformance)):
    if 'Theater' in resultPerformance[i]:
        theater.append(resultMusic[i])

theater
# Out:
# [['Pop', 'Ballad', 'Rap/HipHop'],
#  ['Pop', 'Ballad', 'Rap/HipHop'],
#  ['Idol', 'Dance', 'R&B/Soul'],
#  ['Pop', 'R&B/Soul', 'Rock/Metal'],
#  ['Pop', 'Ballad', 'R&B/Soul'],
#  ['Pop', 'Ballad', 'Dance'],
#  ['Pop', 'Dance', 'R&B/Soul'],
#  ['Pop', 'Ballad', 'Indie'],
#  ['Ballad', 'Dance', 'Rap/HipHop'],
#  ['Pop', 'Ballad', 'Dance'],
#  ['Idol', 'Ballad', 'R&B/Soul'],
#  ['Pop', 'Idol', 'Dance'],
#  ['Pop', 'Idol', 'Dance'],
#  ['Pop', 'Rap/HipHop', 'R&B/Soul'],
#  ['Pop', 'Ballad', 'Indie'],
#  ['Pop', 'Idol', 'Dance'],
#  ['Pop', 'Idol', 'Indie'],
#  ['Idol', 'R&B/Soul', 'Indie'],
#  ['Pop', 'Ballad', 'R&B/Soul'],
#  ['Ballad', 'Rap/HipHop', 'R&B/Soul'],
#  ['Pop', 'R&B/Soul', 'Rock/Metal']]

# %%
#Dance table
dance = []
for i in range(len(resultPerformance)):
    if 'Dance' in resultPerformance[i]:
        dance.append(resultMusic[i])

dance
# Out:
# [['Pop', 'Ballad', 'Dance'],
#  ['Pop', 'Ballad', 'R&B/Soul'],
#  ['Pop', 'Idol', 'Ballad'],
#  ['Idol', 'Dance', 'Rap/HipHop'],
#  ['Idol', 'Ballad', 'Rap/HipHop'],
#  ['Pop', 'Dance', 'R&B/Soul'],
#  ['Pop', 'Ballad', 'R&B/Soul'],
#  ['Idol', 'Ballad', 'Dance'],
#  ['Pop', 'Idol', 'Dance'],
#  ['Pop', 'Rap/HipHop', 'R&B/Soul'],
#  ['Idol', 'Dance', 'Rock/Metal'],
#  ['Idol', 'Ballad', 'Dance'],
#  ['Pop', 'Dance', 'R&B/Soul'],
#  ['Dance', 'Rap/HipHop', 'Rock/Metal'],
#  ['Pop', 'Idol', 'Rap/HipHop'],
#  ['Pop', 'Idol', 'Rap/HipHop'],
#  ['Pop', 'Ballad', 'Dance'],
#  ['Dance', 'Rap/HipHop', 'R&B/Soul'],
#  ['Dance', 'Rap/HipHop', 'Indie'],
#  ['Pop', 'Ballad', 'R&B/Soul'],
#  ['Pop', 'Idol', 'Dance'],
#  ['Pop', 'R&B/Soul', 'Indie'],
#  ['Pop', 'Ballad', 'Rap/HipHop'],
#  ['Pop', 'Indie', 'alternative']]

# %%
#Music Performance table
musicPerformance = []

for i in range(len(resultPerformance)):
    if 'MusicPerformances' in resultPerformance[i]:
        musicPerformance.append(resultMusic[i])

musicPerformance
# Out:
# [['Pop', 'Ballad', 'Dance'],
#  ['Rap/HipHop', 'R&B/Soul', 'Rock/Metal'],
#  ['Pop', 'Ballad', 'R&B/Soul'],
#  ['Pop', 'Rap/HipHop', 'Indie'],
#  ['Pop', 'Idol', 'Ballad'],
#  ['Rap/HipHop', 'R&B/Soul', 'Indie'],
#  ['Rap/HipHop', 'Indie', 'Rock/Metal'],
#  ['Ballad', 'Rap/HipHop', 'R&B/Soul'],
#  ['Pop', 'Rap/HipHop', 'Rock/Metal'],
#  ['Ballad', 'Rap/HipHop', 'R&B/Soul'],
#  ['Ballad', 'Rap/HipHop', 'Indie'],
#  ['Ballad', 'Rap/HipHop', 'R&B/Soul'],
#  ['Dance', 'Rap/HipHop', 'Rock/Metal'],
#  ['Pop', 'Rap/HipHop', 'Rock/Metal'],
#  ['Rap/HipHop', 'R&B/Soul', 'Indie'],
#  ['Rap/HipHop', 'R&B/Soul', 'Indie'],
#  ['Pop', 'Idol', 'Dance'],
#  ['Pop', 'Idol', 'Rock/Metal'],
#  ['Pop', 'Ballad', 'Indie'],
#  ['Pop', 'Idol', 'Dance'],
#  ['Pop', 'R&B/Soul', 'Indie'],
#  ['Pop', 'Ballad', 'R&B/Soul'],
#  ['Pop', 'Idol', 'Ballad'],
#  ['Idol', 'Ballad', 'R&B/Soul'],
#  ['Pop', 'Dance', 'Kpop'],
#  ['Pop', 'Indie', 'TWICE'],
#  ['Pop', 'R&B/Soul', 'Rock/Metal'],
#  ['Pop', 'Dance', 'R&B/Soul'],
#  ['Pop', 'Rap/HipHop', 'Indie'],
#  ['Idol', 'Ballad', 'Dance'],
#  ['Pop', 'Idol', 'Trot'],
#  ['Pop', 'Ballad', 'R&B/Soul'],
#  ['Idol', 'Ballad', 'Dance'],
#  ['Pop', 'Dance', 'Rock/Metal'],
#  ['Pop', 'Ballad', 'Indie'],
#  ['Pop', 'Rap/HipHop', 'Indie'],
#  ['Pop', 'Idol', 'R&B/Soul'],
#  ['Pop', 'Idol', 'Ballad'],
#  ['Pop', 'Idol', 'Ballad'],
#  ['Idol', 'Ballad', 'Dance'],
#  ['Pop', 'Idol', 'Rock/Metal'],
#  ['Pop', 'Rap/HipHop', 'Indie'],
#  ['Pop', 'Ballad', 'Rock/Metal'],
#  ['Pop', 'Rock/Metal', 'EDM'],
#  ['Idol', 'Ballad', 'Rap/HipHop'],
#  ['Pop', 'Idol', 'Dance'],
#  ['Pop', 'Rap/HipHop', 'Rock/Metal'],
#  ['Pop', 'Dance', 'Indie'],
#  ['Pop', 'Rap/HipHop', 'R&B/Soul'],
#  ['Pop', 'Indie', 'Rock/Metal'],
#  ['Pop', 'Ballad', 'Indie'],
#  ['Pop', 'Dance', 'Indie'],
#  ['Pop', 'Rap/HipHop', 'R&B/Soul'],
#  ['Pop', 'Ballad', 'R&B/Soul'],
#  ['Pop', 'Rap/HipHop', 'Rock/Metal'],
#  ['Pop', 'Ballad', 'Rap/HipHop'],
#  ['Pop', 'Idol', 'Rock/Metal'],
#  ['Pop', 'Rap/HipHop', 'R&B/Soul'],
#  ['Pop', 'Idol', 'Rap/HipHop'],
#  ['Ballad', 'Rap/HipHop', 'R&B/Soul'],
#  ['Pop', 'Dance', 'Rap/HipHop'],
#  ['Rap/HipHop', 'R&B/Soul', 'Indie'],
#  ['Pop', 'Idol', 'Rock/Metal'],
#  ['Pop', 'Rap/HipHop', 'Indie'],
#  ['Pop', 'Rap/HipHop', 'R&B/Soul'],
#  ['Pop', 'Idol', 'Indie'],
#  ['Pop', 'Idol', 'Indie'],
#  ['Pop', 'Dance', 'Indie'],
#  ['Pop', 'R&B/Soul', 'Indie'],
#  ['Pop', 'Indie', 'alternative'],
#  ['Pop', 'Rap/HipHop', 'EDM'],
#  ['Pop', 'Ballad', 'R&B/Soul'],
#  ['Pop', 'Idol', 'R&B/Soul'],
#  ['Pop', 'Rap/HipHop', 'R&B/Soul'],
#  ['Idol', 'Dance', 'Indie'],
#  ['Dance', 'Rap/HipHop', 'R&B/Soul'],
#  ['Idol', 'Ballad', 'Rock/Metal']]

# %%
#Traditional Art table 버림
traditionalArt = []

for i in range(len(resultPerformance)):
    if 'TraditionalArt' in resultPerformance[i]:
        traditionalArt.append(resultMusic[i])

traditionalArt
# Out:
# [['Idol', 'Ballad', 'Indie'],
#  ['Pop', 'Ballad', 'R&B/Soul'],
#  ['Pop', 'Ballad', 'R&B/Soul']]

# %%
#Interdisciplinary Art table 버림
interdisciplinaryArt = []

for i in range(len(resultPerformance)):
    if 'InterdisciplinaryArt' in resultPerformance[i]:
        interdisciplinaryArt.append(resultMusic[i])

interdisciplinaryArt
# Out:
# [['Pop', 'Indie', 'Rock/Metal'],
#  ['Pop', 'Ballad', '씹덕노래'],
#  ['Pop', 'Dance', 'Rock/Metal']]

# %%
#Traditional Art table이랑 Interdisciplinary Art table 버렸어

#Theater Apriori
te = TransactionEncoder()
te_ary = te.fit(theater).transform(theater)
concluded = pd.DataFrame(te_ary, columns=te.columns_)
tempApriori = apriori(concluded, min_support=0.3, use_colnames=True)

theaterApriori = tempApriori.sort_values(["support"], ascending=[False])
theaterApriori
# Out:
#     support       itemsets
# 3  0.761905          (Pop)
# 0  0.523810       (Ballad)
# 4  0.476190     (R&B/Soul)
# 1  0.380952        (Dance)
# 5  0.380952  (Ballad, Pop)
# 2  0.333333         (Idol)

# %%
#Dance Apriori
te = TransactionEncoder()
te_ary = te.fit(dance).transform(dance)
concluded = pd.DataFrame(te_ary, columns=te.columns_)
tempApriori = apriori(concluded, min_support=0.3, use_colnames=True)

danceApriori = tempApriori.sort_values(["support"], ascending=[False])
danceApriori
# Out:
#     support      itemsets
# 3  0.666667         (Pop)
# 1  0.541667       (Dance)
# 0  0.416667      (Ballad)
# 2  0.416667        (Idol)
# 5  0.375000  (Rap/HipHop)
# 4  0.333333    (R&B/Soul)

# %%
#Music Performance Apriori
te = TransactionEncoder()
te_ary = te.fit(musicPerformance).transform(musicPerformance)
concluded = pd.DataFrame(te_ary, columns=te.columns_)
tempApriori = apriori(concluded, min_support=0.3, use_colnames=True)

musicPerformanceApriori = tempApriori.sort_values(["support"], ascending=[False])
musicPerformanceApriori
# Out:
#     support      itemsets
# 3  0.740260         (Pop)
# 5  0.415584  (Rap/HipHop)
# 4  0.350649    (R&B/Soul)
# 0  0.337662      (Ballad)
# 2  0.324675       (Indie)
# 1  0.311688        (Idol)

# %%
#Musical table
musical = []

for i in range(len(resultPerformance)):
    if 'Musical' in resultPerformance[i]:
        musical.append(resultMusic[i])

musical
# Out:
# [['Idol', 'Ballad', 'Dance'],
#  ['Rap/HipHop', 'R&B/Soul', 'Rock/Metal'],
#  ['Pop', 'Ballad', 'Indie'],
#  ['Pop', 'Dance', 'Rock/Metal'],
#  ['Pop', 'Rap/HipHop', 'R&B/Soul'],
#  ['Idol', 'Ballad', 'Dance'],
#  ['Pop', 'R&B/Soul', 'Rock/Metal'],
#  ['Idol', 'Ballad', 'Indie'],
#  ['Pop', 'Idol', 'Ballad'],
#  ['Pop', 'Ballad', 'orchestral'],
#  ['Pop', 'Ballad', 'Dance'],
#  ['Pop', 'Ballad', 'R&B/Soul'],
#  ['Pop', 'Rap/HipHop', 'R&B/Soul'],
#  ['Pop', 'Rap/HipHop', 'R&B/Soul'],
#  ['Pop', 'Ballad', 'Dance'],
#  ['Pop', 'Ballad', 'R&B/Soul'],
#  ['Pop', 'Ballad', 'Dance'],
#  ['Pop', 'R&B/Soul', 'Rock/Metal'],
#  ['Ballad', 'R&B/Soul', 'Indie'],
#  ['Idol', 'Ballad', 'Dance'],
#  ['Ballad', 'R&B/Soul', 'Indie'],
#  ['Idol', 'Ballad', 'Indie'],
#  ['Ballad', 'R&B/Soul', 'Indie'],
#  ['Idol', 'Dance', 'R&B/Soul'],
#  ['Pop', 'Idol', 'Dance'],
#  ['Pop', 'Rap/HipHop', 'R&B/Soul'],
#  ['Pop', 'Dance', 'Rock/Metal'],
#  ['Pop', 'Idol', 'Ballad'],
#  ['Pop', 'Rock/Metal', '클래식'],
#  ['Pop', 'Rap/HipHop', 'Rock/Metal'],
#  ['Pop', 'Ballad', 'R&B/Soul'],
#  ['Ballad', 'Dance', 'R&B/Soul'],
#  ['Pop', 'Idol', 'Ballad'],
#  ['Pop', 'Ballad', 'Indie'],
#  ['Idol', 'Ballad', 'Indie'],
#  ['Pop', 'Idol', 'Rock/Metal'],
#  ['Pop', 'Idol', 'R&B/Soul'],
#  ['Pop', 'Idol', 'Dance'],
#  ['Idol', 'Rap/HipHop', 'R&B/Soul'],
#  ['Pop', 'R&B/Soul', 'Indie'],
#  ['Pop', 'R&B/Soul', 'Rock/Metal']]

# %%
#Musical Apriori
te = TransactionEncoder()
te_ary = te.fit(musical).transform(musical)
concluded = pd.DataFrame(te_ary, columns=te.columns_)
tempApriori = apriori(concluded, min_support=0.3, use_colnames=True)

musicalApriori = tempApriori.sort_values(["support"], ascending=[False])
musicalApriori
# Out:
#     support    itemsets
# 2  0.682927       (Pop)
# 0  0.536585    (Ballad)
# 3  0.463415  (R&B/Soul)
# 1  0.365854      (Idol)

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

#Data 불러오기
roughResult = pd.read_csv('BI_data_new.csv')
exhibitionData = roughResult.iloc[:,[1,4]]
exhibitionData.head()
# Out:
#   What genre of music do you most likely to listen to?(Select 3 )  \
# 0                  Pop (팝), Ballad (발라드), Dance (댄스)
# 1  Rap/ Hip Hop (랩/힙합), R&B / Soul (R&B/소울), Rock...
# 2         Pop (팝), Ballad (발라드), R&B / Soul (R&B/소울)
# 3           Pop (팝), Rap/ Hip Hop (랩/힙합), Indie (인디)
# 4               Idol (아이돌), Ballad (발라드), Dance (댄스)
#
#   What kind of art exhibitions do you like the most? / 가장 좋아하는 전시회는 무엇입니까?
# 0                                    Sculptures (조각)
# 1                                     Paintings (회화)
# 2                                   Photography (사진)
# 3                                   Art Design (디자인)
# 4                                   Art Design (디자인)

# %%
#Exhibition 정제
resultExhibition = []
for j in range(len(artPerformanceData)):
    resultE1 = exhibitionData.iloc[j, 1].split('(')

    resultExhibition.append(resultE1[0].replace(" ", ""))
    
resultExhibition
# Out:
# ['Sculptures',
#  'Paintings',
#  'Photography',
#  'ArtDesign',
#  'ArtDesign',
#  'Photography',
#  'Photography',
#  'Sculptures',
#  'Photography',
#  'Photography',
#  'Crafting',
#  'Paintings',
#  'Paintings',
#  'ArtDesign',
#  'ArtDesign',
#  'Paintings',
#  'Photography',
#  'ㆍ',
#  'Sculptures',
#  'Photography',
#  'Paintings',
#  'ArtDesign',
#  'Photography',
#  'Photography',
#  'ArtDesign',
#  'Photography',
#  'Crafting',
#  'Photography',
#  'Photography',
#  'ArtDesign',
#  'Paintings',
#  'Architecture',
#  'Photography',
#  'ArtDesign',
#  'Photography',
#  'Sculptures',
#  'Photography',
#  'Paintings',
#  'Photography',
#  'Photography',
#  'Paintings',
#  'Paintings',
#  'Paintings',
#  'ArtDesign',
#  'Architecture',
#  'Paintings',
#  'ArtDesign',
#  'ArtDesign',
#  'Architecture',
#  'Photography',
#  'Paintings',
#  'Paintings',
#  'Paintings',
#  'Sculptures',
#  'ArtDesign',
#  'Paintings',
#  'Crafting',
#  'Paintings',
#  'Paintings',
#  'Crafting',
#  'ArtDesign',
#  'Paintings',
#  'Crafting',
#  'Paintings',
#  'Photography',
#  'Paintings',
#  'Architecture',
#  'ArtDesign',
#  'Photography',
#  'Photography',
#  'ArtDesign',
#  'Photography',
#  'Architecture',
#  'Architecture',
#  'Paintings',
#  'Paintings',
#  'Architecture',
#  'Paintings',
#  'Photography',
#  'Photography',
#  'Architecture',
#  'Architecture',
#  'Food',
#  'Architecture',
#  'Paintings',
#  'Paintings',
#  'ArtDesign',
#  'Architecture',
#  'Photography',
#  'Architecture',
#  'Sculptures',
#  'ArtDesign',
#  'Photography',
#  'Crafting',
#  'Photography',
#  'Paintings',
#  'Photography',
#  'Paintings',
#  'Photography',
#  'ArtDesign',
#  'Photography',
#  'Photography',
#  'Architecture',
#  'Architecture',
#  'Crafting',
#  'Photography',
#  'Crafting',
#  'ArtDesign',
#  'Paintings',
#  'Paintings',
#  'Architecture',
#  'Crafting',
#  'Crafting',
#  'Photography',
#  'Architecture',
#  'Photography',
#  'ArtDesign',
#  'Paintings',
#  'Crafting',
#  'Photography',
#  'Photography',
#  '흥미를끄는주제의모든전시',
#  'Architecture',
#  'ArtDesign',
#  'Paintings',
#  'Paintings',
#  'Paintings',
#  'Crafting',
#  'ArtDesign',
#  'Photography',
#  'ArtDesign',
#  'ArtDesign',
#  'ArtDesign',
#  'Paintings',
#  'Photography',
#  'Photography',
#  'ArtDesign',
#  'Sculptures',
#  'Paintings',
#  'Paintings',
#  'Photography',
#  '전시회는다싫습니다',
#  'Photography',
#  'Photography',
#  'Paintings',
#  'Crafting',
#  'Paintings',
#  'Sculptures',
#  'Paintings',
#  'Paintings',
#  'Photography',
#  'Photography',
#  'Photography',
#  'Sculptures',
#  'Photography',
#  'Architecture',
#  'ArtDesign',
#  'Sculptures',
#  'ArtDesign',
#  'ArtDesign',
#  'Photography',
#  'Paintings',
#  'Paintings',
#  'ArtDesign',
#  'Paintings',
#  'Photography',
#  'Photography',
#  'ArtDesign',
#  'ArtDesign',
#  'Photography',
#  'Paintings',
#  'Crafting']

# %%
#Paintings table
paintings = []
for i in range(len(resultExhibition)):
    if 'Paintings' in resultExhibition[i]:
        paintings.append(resultMusic[i])

paintings
# Out:
# [['Rap/HipHop', 'R&B/Soul', 'Rock/Metal'],
#  ['Pop', 'Indie', 'Rock/Metal'],
#  ['Rap/HipHop', 'R&B/Soul', 'Indie'],
#  ['Ballad', 'Rap/HipHop', 'R&B/Soul'],
#  ['Pop', 'Ballad', 'Dance'],
#  ['Pop', 'Ballad', 'R&B/Soul'],
#  ['Pop', 'Idol', 'Dance'],
#  ['Pop', 'R&B/Soul', 'Indie'],
#  ['Pop', 'Ballad', 'R&B/Soul'],
#  ['Idol', 'Ballad', 'Rap/HipHop'],
#  ['Pop', 'Ballad', 'orchestral'],
#  ['Pop', 'Indie', 'TWICE'],
#  ['Pop', 'R&B/Soul', 'Rock/Metal'],
#  ['Pop', 'Idol', 'Dance'],
#  ['Pop', 'Rap/HipHop', 'R&B/Soul'],
#  ['Pop', 'Rap/HipHop', 'R&B/Soul'],
#  ['Idol', 'Dance', 'Rock/Metal'],
#  ['Pop', 'Rap/HipHop', 'Indie'],
#  ['Pop', 'Ballad', 'R&B/Soul'],
#  ['Pop', 'Ballad', 'R&B/Soul'],
#  ['Pop', 'Dance', 'R&B/Soul'],
#  ['Dance', 'Rap/HipHop', 'Rock/Metal'],
#  ['Pop', 'Idol', 'R&B/Soul'],
#  ['Pop', 'Ballad', 'Indie'],
#  ['Idol', 'Ballad', 'Dance'],
#  ['Pop', 'Idol', 'Dance'],
#  ['Pop', 'Rap/HipHop', 'Rock/Metal'],
#  ['Pop', 'Dance', 'Indie'],
#  ['Pop', 'Rap/HipHop', 'R&B/Soul'],
#  ['Pop', 'Idol', 'Dance'],
#  ['Pop', 'Rap/HipHop', 'Rock/Metal'],
#  ['Pop', 'Ballad', 'R&B/Soul'],
#  ['Pop', 'Ballad', 'Indie'],
#  ['Pop', 'Ballad', 'Indie'],
#  ['Pop', 'Idol', 'R&B/Soul'],
#  ['Rap/HipHop', 'R&B/Soul', 'Indie'],
#  ['Dance', 'Rap/HipHop', 'Indie'],
#  ['Pop', 'Ballad', 'R&B/Soul'],
#  ['Pop', 'Idol', 'Indie'],
#  ['Pop', 'R&B/Soul', 'Indie'],
#  ['Pop', 'Ballad', 'R&B/Soul'],
#  ['Pop', 'R&B/Soul', 'Indie'],
#  ['Pop', 'Rap/HipHop', 'R&B/Soul'],
#  ['Pop', 'R&B/Soul', 'Rock/Metal']]

# %%
#Sculptures table
sculptures = []
for i in range(len(resultExhibition)):
    if 'Sculptures' in resultExhibition[i]:
        sculptures.append(resultMusic[i])

sculptures
# Out:
# [['Pop', 'Ballad', 'Dance'],
#  ['Pop', 'Ballad', 'Indie'],
#  ['Ballad', 'Rap/HipHop', 'R&B/Soul'],
#  ['Pop', 'R&B/Soul', 'Rock/Metal'],
#  ['Pop', 'Ballad', 'Dance'],
#  ['Pop', 'Ballad', 'Dance'],
#  ['Pop', 'Idol', 'Rock/Metal'],
#  ['Pop', 'Idol', 'Dance'],
#  ['Pop', 'Dance', 'Rock/Metal'],
#  ['Pop', 'Indie', 'alternative']]

# %%
#Photography table
photography = []
for i in range(len(resultExhibition)):
    if 'Photography' in resultExhibition[i]:
        photography.append(resultMusic[i])

photography
# Out:
# [['Pop', 'Ballad', 'R&B/Soul'],
#  ['Rap/HipHop', 'R&B/Soul', 'Rock/Metal'],
#  ['Pop', 'Idol', 'Ballad'],
#  ['Pop', 'Dance', 'Rock/Metal'],
#  ['Pop', 'Rap/HipHop', 'R&B/Soul'],
#  ['Pop', 'Ballad', '씹덕노래'],
#  ['Ballad', 'Rap/HipHop', 'Indie'],
#  ['Pop', 'Ballad', 'Rap/HipHop'],
#  ['Pop', 'R&B/Soul', 'Rock/Metal'],
#  ['Pop', 'Rap/HipHop', 'Rock/Metal'],
#  ['Rap/HipHop', 'R&B/Soul', 'Indie'],
#  ['Idol', 'Ballad', 'Indie'],
#  ['Pop', 'Idol', 'Dance'],
#  ['Pop', 'Ballad', 'Indie'],
#  ['Pop', 'Idol', 'Ballad'],
#  ['Pop', 'Idol', 'Ballad'],
#  ['Idol', 'Dance', 'Rap/HipHop'],
#  ['Idol', 'Ballad', 'Dance'],
#  ['Pop', 'Idol', 'Trot'],
#  ['Pop', 'Dance', 'R&B/Soul'],
#  ['Pop', 'Ballad', 'R&B/Soul'],
#  ['Pop', 'Ballad', 'Dance'],
#  ['Pop', 'Idol', 'Rap/HipHop'],
#  ['Pop', 'Idol', 'Rap/HipHop'],
#  ['Pop', 'Rap/HipHop', 'Indie'],
#  ['Pop', 'Idol', 'Ballad'],
#  ['Idol', 'Ballad', 'Rap/HipHop'],
#  ['Ballad', 'Dance', 'Rap/HipHop'],
#  ['Pop', 'Ballad', 'Dance'],
#  ['Pop', 'Rap/HipHop', 'R&B/Soul'],
#  ['Ballad', 'R&B/Soul', 'Indie'],
#  ['Pop', 'Ballad', 'Indie'],
#  ['Ballad', 'R&B/Soul', 'Indie'],
#  ['Pop', 'Idol', 'Dance'],
#  ['Pop', 'Dance', 'Rock/Metal'],
#  ['Pop', 'Idol', 'Ballad'],
#  ['Pop', 'Idol', 'Dance'],
#  ['Ballad', 'Rap/HipHop', 'R&B/Soul'],
#  ['Idol', 'Ballad', 'Indie'],
#  ['Pop', 'Idol', 'Indie'],
#  ['Pop', 'Idol', 'Rock/Metal'],
#  ['Pop', 'Rap/HipHop', 'Indie'],
#  ['Pop', 'Ballad', 'Rap/HipHop'],
#  ['Pop', 'Idol', 'Indie'],
#  ['Pop', 'Indie', 'alternative'],
#  ['Idol', 'Rap/HipHop', 'R&B/Soul'],
#  ['Pop', 'Rap/HipHop', 'EDM'],
#  ['Idol', 'Dance', 'Indie'],
#  ['Dance', 'Rap/HipHop', 'R&B/Soul'],
#  ['Ballad', 'Rap/HipHop', 'R&B/Soul']]

# %%
#Art Design table
artDesign = []
for i in range(len(resultExhibition)):
    if 'ArtDesign' in resultExhibition[i]:
        artDesign.append(resultMusic[i])

artDesign
# Out:
# [['Pop', 'Rap/HipHop', 'Indie'],
#  ['Idol', 'Ballad', 'Dance'],
#  ['Idol', 'Ballad', 'Dance'],
#  ['Rap/HipHop', 'Indie', 'Rock/Metal'],
#  ['Ballad', 'Rap/HipHop', 'R&B/Soul'],
#  ['Dance', 'Rap/HipHop', 'Rock/Metal'],
#  ['Rap/HipHop', 'R&B/Soul', 'Indie'],
#  ['Pop', 'Idol', 'Rock/Metal'],
#  ['Pop', 'Dance', 'R&B/Soul'],
#  ['Idol', 'Ballad', 'R&B/Soul'],
#  ['Pop', 'Dance', 'Kpop'],
#  ['Pop', 'Ballad', 'R&B/Soul'],
#  ['Pop', 'Dance', 'R&B/Soul'],
#  ['Idol', 'Ballad', 'Dance'],
#  ['Pop', 'Dance', 'Rock/Metal'],
#  ['Pop', 'Ballad', 'R&B/Soul'],
#  ['Pop', 'Rock/Metal', 'EDM'],
#  ['Pop', 'Dance', 'Indie'],
#  ['Idol', 'Ballad', 'R&B/Soul'],
#  ['Pop', 'Rap/HipHop', 'R&B/Soul'],
#  ['Pop', 'Ballad', 'Rap/HipHop'],
#  ['Ballad', 'Dance', 'R&B/Soul'],
#  ['Pop', 'Rap/HipHop', 'R&B/Soul'],
#  ['Pop', 'Idol', 'Rap/HipHop'],
#  ['Pop', 'Idol', 'Ballad'],
#  ['Pop', 'Dance', 'Rap/HipHop'],
#  ['Pop', 'R&B/Soul', 'Indie'],
#  ['Pop', 'Indie', 'Lofi'],
#  ['Idol', 'R&B/Soul', 'Indie'],
#  ['Pop', 'Idol', 'R&B/Soul'],
#  ['Pop', 'Ballad', 'R&B/Soul'],
#  ['Pop', 'R&B/Soul', 'Rock/Metal']]

# %%
#Crafting table
crafting = []
for i in range(len(resultExhibition)):
    if 'Crafting' in resultExhibition[i]:
        crafting.append(resultMusic[i])

crafting
# Out:
# [['Pop', 'Ballad', 'Rap/HipHop'],
#  ['Idol', 'Ballad', 'Indie'],
#  ['Pop', 'Rap/HipHop', 'R&B/Soul'],
#  ['Pop', 'Ballad', 'R&B/Soul'],
#  ['Idol', 'Ballad', 'Dance'],
#  ['Pop', 'R&B/Soul', 'Rock/Metal'],
#  ['Pop', 'Indie', 'Rock/Metal'],
#  ['Ballad', 'R&B/Soul', 'Indie'],
#  ['Pop', 'Idol', 'Dance'],
#  ['Pop', 'Ballad', 'R&B/Soul'],
#  ['Pop', 'Rap/HipHop', 'R&B/Soul'],
#  ['Pop', 'Idol', 'Rock/Metal'],
#  ['Pop', 'Rap/HipHop', 'R&B/Soul'],
#  ['Idol', 'Ballad', 'Rock/Metal']]

# %%
#Architecture table
architecture = []
for i in range(len(resultExhibition)):
    if 'Architecture' in resultExhibition[i]:
        architecture.append(resultMusic[i])

architecture
# Out:
# [['Idol', 'Dance', 'R&B/Soul'],
#  ['Pop', 'Idol', 'Ballad'],
#  ['Pop', 'Ballad', 'R&B/Soul'],
#  ['Idol', 'Ballad', 'Dance'],
#  ['Pop', 'Ballad', 'Dance'],
#  ['Pop', 'Ballad', 'Indie'],
#  ['Pop', 'Rap/HipHop', 'Indie'],
#  ['Pop', 'Idol', 'Ballad'],
#  ['Pop', 'Idol', 'Ballad'],
#  ['Pop', 'Ballad', 'Dance'],
#  ['Pop', 'Idol', 'Rock/Metal'],
#  ['Pop', 'Ballad', 'Rock/Metal'],
#  ['Idol', 'Ballad', 'Dance'],
#  ['Dance', 'Rap/HipHop', 'R&B/Soul'],
#  ['Idol', 'Ballad', 'Indie'],
#  ['Idol', 'Dance', 'R&B/Soul'],
#  ['Pop', 'Rap/HipHop', 'Rock/Metal'],
#  ['Pop', 'Dance', 'Indie']]

# %%
#하나도 안 버림

#Paintings Apriori
te = TransactionEncoder()
te_ary = te.fit(paintings).transform(paintings)
concluded = pd.DataFrame(te_ary, columns=te.columns_)
tempApriori = apriori(concluded, min_support=0.3, use_colnames=True)

paintingsApriori = tempApriori.sort_values(["support"], ascending=[False])
paintingsApriori
# Out:
#     support         itemsets
# 2  0.795455            (Pop)
# 3  0.522727       (R&B/Soul)
# 5  0.431818  (Pop, R&B/Soul)
# 0  0.340909         (Ballad)
# 1  0.318182          (Indie)
# 4  0.318182     (Rap/HipHop)

# %%
#Sculptures Apriori
te = TransactionEncoder()
te_ary = te.fit(sculptures).transform(sculptures)
concluded = pd.DataFrame(te_ary, columns=te.columns_)
tempApriori = apriori(concluded, min_support=0.3, use_colnames=True)

sculpturesApriori = tempApriori.sort_values(["support"], ascending=[False])
sculpturesApriori
# Out:
#    support              itemsets
# 2      0.9                 (Pop)
# 0      0.5              (Ballad)
# 1      0.5               (Dance)
# 6      0.5          (Pop, Dance)
# 5      0.4         (Ballad, Pop)
# 3      0.3          (Rock/Metal)
# 4      0.3       (Ballad, Dance)
# 7      0.3     (Pop, Rock/Metal)
# 8      0.3  (Ballad, Pop, Dance)

# %%
#Photography Apriori
te = TransactionEncoder()
te_ary = te.fit(photography).transform(photography)
concluded = pd.DataFrame(te_ary, columns=te.columns_)
tempApriori = apriori(concluded, min_support=0.3, use_colnames=True)

photographyApriori = tempApriori.sort_values(["support"], ascending=[False])
photographyApriori
# Out:
#    support      itemsets
# 2     0.68         (Pop)
# 0     0.48      (Ballad)
# 1     0.42        (Idol)
# 3     0.40  (Rap/HipHop)

# %%
#Art Design Apriori
te = TransactionEncoder()
te_ary = te.fit(artDesign).transform(artDesign)
concluded = pd.DataFrame(te_ary, columns=te.columns_)
tempApriori = apriori(concluded, min_support=0.3, use_colnames=True)

artDesignApriori = tempApriori.sort_values(["support"], ascending=[False])
artDesignApriori
# Out:
#    support         itemsets
# 3  0.65625            (Pop)
# 4  0.50000       (R&B/Soul)
# 0  0.37500         (Ballad)
# 1  0.34375          (Dance)
# 2  0.31250           (Idol)
# 5  0.31250     (Rap/HipHop)
# 6  0.31250  (Pop, R&B/Soul)

# %%
#Crafting Apriori
te = TransactionEncoder()
te_ary = te.fit(crafting).transform(crafting)
concluded = pd.DataFrame(te_ary, columns=te.columns_)
tempApriori = apriori(concluded, min_support=0.3, use_colnames=True)

craftingApriori = tempApriori.sort_values(["support"], ascending=[False])
craftingApriori
# Out:
#     support         itemsets
# 2  0.714286            (Pop)
# 0  0.500000         (Ballad)
# 3  0.500000       (R&B/Soul)
# 4  0.428571  (Pop, R&B/Soul)
# 1  0.357143           (Idol)

# %%
#Architecture Apriori
te = TransactionEncoder()
te_ary = te.fit(architecture).transform(architecture)
concluded = pd.DataFrame(te_ary, columns=te.columns_)
tempApriori = apriori(concluded, min_support=0.3, use_colnames=True)

architectureApriori = tempApriori.sort_values(["support"], ascending=[False])
architectureApriori
# Out:
#     support        itemsets
# 3  0.666667           (Pop)
# 0  0.611111        (Ballad)
# 2  0.500000          (Idol)
# 1  0.444444         (Dance)
# 5  0.444444   (Ballad, Pop)
# 4  0.333333  (Ballad, Idol)
