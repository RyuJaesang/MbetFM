# %%
import pandas as pd

list_data = pd.read_csv('bi_data.csv')
list_data.head()
# Out:
#                     타임스탬프  \
# 0  2019. 11. 7 오후 6:03:37
# 1  2019. 11. 7 오후 6:04:10
# 2  2019. 11. 7 오후 6:10:23
# 3  2019. 11. 7 오후 6:10:27
# 4  2019. 11. 7 오후 6:10:44
#
#   What genre of music do you most likely to listen to? /가장 좋아하는 음악 장르는 무엇입니까?(Select 3 / 3가지 선택)  \
# 0       Pop / Idol (팝/아이돌), Ballad (발라드), Dance (댄스)
# 1  Rap/ Hip Hop (랩/힙합), R&B / Soul (R&B/소울), Rock...
# 2         Pop (팝), Ballad (발라드), R&B / Soul (R&B/소울)
# 3           Pop (팝), Rap/ Hip Hop (랩/힙합), Indie (인디)
# 4               Idol (아이돌), Ballad (발라드), Dance (댄스)
#
#   What kind of fashion style do you like the most? / 가장 좋아하는 패션 스타일은 무엇입니까? (Select 3 / 3가지 선택)  \
# 0  Workwear (워크웨어륵) (constructed of sturdy fabric...
# 1  Casual (캐주얼룩), Workwear (워크웨어륵) (constructed o...
# 2  Casual (캐주얼룩), Workwear (워크웨어륵) (constructed o...
# 3  Casual (캐주얼룩), Workwear (워크웨어륵) (constructed o...
# 4  Casual (캐주얼룩), Workwear (워크웨어륵) (constructed o...
#
# ...

# %%
import pandas as pd

list_data = pd.read_csv('bi_data.csv')
list_data
# Out:
#                         타임스탬프  \
# 0      2019. 11. 7 오후 6:03:37
# 1      2019. 11. 7 오후 6:04:10
# 2      2019. 11. 7 오후 6:10:23
# 3      2019. 11. 7 오후 6:10:27
# 4      2019. 11. 7 오후 6:10:44
# ..                        ...
# 161   2019. 11. 15 오후 4:07:30
# 162   2019. 11. 15 오후 4:36:31
# 163   2019. 11. 15 오후 5:51:09
# 164   2019. 11. 16 오후 5:16:58
# 165  2019. 11. 19 오전 11:42:31
#
#     What genre of music do you most likely to listen to? /가장 좋아하는 음악 장르는 무엇입니까?(Select 3 / 3가지 선택)  \
# 0         Pop / Idol (팝/아이돌), Ballad (발라드), Dance (댄스)
# 1    Rap/ Hip Hop (랩/힙합), R&B / Soul (R&B/소울), Rock...
# 2           Pop (팝), Ballad (발라드), R&B / Soul (R&B/소울)
# 3             Pop (팝), Rap/ Hip Hop (랩/힙합), Indie (인디)
# 4                 Idol (아이돌), Ballad (발라드), Dance (댄스)
# ..                                                 ...
# 161         Pop (팝), Ballad (발라드), R&B / Soul (R&B/소울)
# 162           Pop (팝), R&B / Soul (R&B/소울), Indie (인디)
# ...

# %%
import findspark
findspark.init()
from pyspark.mllib.fpm import FPGrowth

data = sc.textFile("bi_data.txt")
transactions = data.map(lambda line: line.strip().split(' '))
model = FPGrowth.train(transactions, minSupport=0.2, numPartitions=10)
result = model.freqItemsets().collect()
for fi in result:
    print(fi)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-b078727c7183> in <module>
#       1 import findspark
# ----> 2 findspark.init()
#       3 from pyspark.mllib.fpm import FPGrowth
#       4
#       5 data = sc.textFile("bi_data.txt")
#
# ~\Anaconda3\lib\site-packages\findspark.py in init(spark_home, python_path, edit_rc, edit_profile)
#     133     # add pyspark to sys.path
#     134     spark_python = os.path.join(spark_home, 'python')
# --> 135     py4j = glob(os.path.join(spark_python, 'lib', 'py4j-*.zip'))[0]
#     136     sys.path[:0] = [spark_python, py4j]
#     137
#
# IndexError: list index out of range

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit("bi_data.csv").transform("bi_data.csv")
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#         .      _      a      b      c      d      i      s      t      v
# 0   False  False  False   True  False  False  False  False  False  False
# 1   False  False  False  False  False  False   True  False  False  False
# 2   False   True  False  False  False  False  False  False  False  False
# 3   False  False  False  False  False   True  False  False  False  False
# 4   False  False   True  False  False  False  False  False  False  False
# 5   False  False  False  False  False  False  False  False   True  False
# 6   False  False   True  False  False  False  False  False  False  False
# 7    True  False  False  False  False  False  False  False  False  False
# 8   False  False  False  False   True  False  False  False  False  False
# 9   False  False  False  False  False  False  False   True  False  False
# 10  False  False  False  False  False  False  False  False  False   True

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit("bi_data.txt").transform("bi_data.txt")
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#         .      _      a      b      d      i      t      x
# 0   False  False  False   True  False  False  False  False
# 1   False  False  False  False  False   True  False  False
# 2   False   True  False  False  False  False  False  False
# 3   False  False  False  False   True  False  False  False
# 4   False  False   True  False  False  False  False  False
# 5   False  False  False  False  False  False   True  False
# 6   False  False   True  False  False  False  False  False
# 7    True  False  False  False  False  False  False  False
# 8   False  False  False  False  False  False   True  False
# 9   False  False  False  False  False  False  False   True
# 10  False  False  False  False  False  False   True  False

# %%
from mlxtend.frequent_patterns import fpgrowth

fpgrowth(df, min_support=0.6)
# Out:
# Empty DataFrame
# Columns: [support, itemsets]
# Index: []

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth

te = TransactionEncoder()
fpgrowth(df, min_support=0.6)
te_ary = te.fit("bi_data.txt").transform("bi_data.txt")
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#         .      _      a      b      d      i      t      x
# 0   False  False  False   True  False  False  False  False
# 1   False  False  False  False  False   True  False  False
# 2   False   True  False  False  False  False  False  False
# 3   False  False  False  False   True  False  False  False
# 4   False  False   True  False  False  False  False  False
# 5   False  False  False  False  False  False   True  False
# 6   False  False   True  False  False  False  False  False
# 7    True  False  False  False  False  False  False  False
# 8   False  False  False  False  False  False   True  False
# 9   False  False  False  False  False  False  False   True
# 10  False  False  False  False  False  False   True  False

# %%
import findspark
findspark.init(r'C:\Users\anism\Desktop\python')
import pyspark
from pyspark.mllib.fpm import FPGrowth

data = sc.textFile("bi_data.txt")
transactions = data.map(lambda line: line.strip().split(' '))
model = FPGrowth.train(transactions, minSupport=0.2, numPartitions=10)
result = model.freqItemsets().collect()
for fi in result:
    print(fi)
# Out:
#   File "<ipython-input-6-02055ba898b8>", line 2
#     findspark.init('C:\Users\anism\Desktop\python')
#                   ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import findspark
findspark.init('C:\Users\anism\Desktop\python')
import pyspark
from pyspark.mllib.fpm import FPGrowth

data = sc.textFile("bi_data.txt")
transactions = data.map(lambda line: line.strip().split(' '))
model = FPGrowth.train(transactions, minSupport=0.2, numPartitions=10)
result = model.freqItemsets().collect()
for fi in result:
    print(fi)
# Out:
#   File "<ipython-input-8-02055ba898b8>", line 2
#     findspark.init('C:\Users\anism\Desktop\python')
#                   ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import csv
data = open(r"C:\Users\anism\Desktop\python")
data = csv.reader("bi_data.csv")  
print("bi_data.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-9-ab941ee92623> in <module>
#       1 import csv
# ----> 2 data = open(r"C:\Users\anism\Desktop\python")
#       3 data = csv.reader("bi_data.csv")
#       4 print("bi_data.csv")
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\anism\\Desktop\\python'

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth

te = TransactionEncoder()
fpgrowth(df, min_support=0.6)
te_ary = te.fit("bi_data.txt").transform("bi_data.txt")
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-6b1b9fbb96a1> in <module>
#       4
#       5 te = TransactionEncoder()
# ----> 6 fpgrowth(df, min_support=0.6)
#       7 te_ary = te.fit("bi_data.txt").transform("bi_data.txt")
#       8 df = pd.DataFrame(te_ary, columns=te.columns_)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit("bi_data.csv").transform("bi_data.csv")
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#         .      _      a      b      c      d      i      s      t      v
# 0   False  False  False   True  False  False  False  False  False  False
# 1   False  False  False  False  False  False   True  False  False  False
# 2   False   True  False  False  False  False  False  False  False  False
# 3   False  False  False  False  False   True  False  False  False  False
# 4   False  False   True  False  False  False  False  False  False  False
# 5   False  False  False  False  False  False  False  False   True  False
# 6   False  False   True  False  False  False  False  False  False  False
# 7    True  False  False  False  False  False  False  False  False  False
# 8   False  False  False  False   True  False  False  False  False  False
# 9   False  False  False  False  False  False  False   True  False  False
# 10  False  False  False  False  False  False  False  False  False   True

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth

te = TransactionEncoder()
fpgrowth(df, min_support=1.0)
te_ary = te.fit("bi_data.txt").transform("bi_data.txt")
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#         .      _      a      b      d      i      t      x
# 0   False  False  False   True  False  False  False  False
# 1   False  False  False  False  False   True  False  False
# 2   False   True  False  False  False  False  False  False
# 3   False  False  False  False   True  False  False  False
# 4   False  False   True  False  False  False  False  False
# 5   False  False  False  False  False  False   True  False
# 6   False  False   True  False  False  False  False  False
# 7    True  False  False  False  False  False  False  False
# 8   False  False  False  False  False  False   True  False
# 9   False  False  False  False  False  False  False   True
# 10  False  False  False  False  False  False   True  False

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit("bi_data1.csv").transform("bi_data1.csv")
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#         .      1      _      a      b      c      d      i      s      t  \
# 0   False  False  False  False   True  False  False  False  False  False
# 1   False  False  False  False  False  False  False   True  False  False
# 2   False  False   True  False  False  False  False  False  False  False
# 3   False  False  False  False  False  False   True  False  False  False
# 4   False  False  False   True  False  False  False  False  False  False
# 5   False  False  False  False  False  False  False  False  False   True
# 6   False  False  False   True  False  False  False  False  False  False
# 7   False   True  False  False  False  False  False  False  False  False
# 8    True  False  False  False  False  False  False  False  False  False
# 9   False  False  False  False  False   True  False  False  False  False
# 10  False  False  False  False  False  False  False  False   True  False
# 11  False  False  False  False  False  False  False  False  False  False
#
#         v
# ...

# %%
import pandas as pd

list_data = pd.read_csv('bi_data.csv')
list_data
# Out:
#                         타임스탬프  \
# 0      2019. 11. 7 오후 6:03:37
# 1      2019. 11. 7 오후 6:04:10
# 2      2019. 11. 7 오후 6:10:23
# 3      2019. 11. 7 오후 6:10:27
# 4      2019. 11. 7 오후 6:10:44
# ..                        ...
# 161   2019. 11. 15 오후 4:07:30
# 162   2019. 11. 15 오후 4:36:31
# 163   2019. 11. 15 오후 5:51:09
# 164   2019. 11. 16 오후 5:16:58
# 165  2019. 11. 19 오전 11:42:31
#
#     What genre of music do you most likely to listen to? /가장 좋아하는 음악 장르는 무엇입니까?(Select 3 / 3가지 선택)  \
# 0         Pop / Idol (팝/아이돌), Ballad (발라드), Dance (댄스)
# 1    Rap/ Hip Hop (랩/힙합), R&B / Soul (R&B/소울), Rock...
# 2           Pop (팝), Ballad (발라드), R&B / Soul (R&B/소울)
# 3             Pop (팝), Rap/ Hip Hop (랩/힙합), Indie (인디)
# 4                 Idol (아이돌), Ballad (발라드), Dance (댄스)
# ..                                                 ...
# 161         Pop (팝), Ballad (발라드), R&B / Soul (R&B/소울)
# 162           Pop (팝), R&B / Soul (R&B/소울), Indie (인디)
# ...

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit("bi_data.csv").transform("bi_data.csv")
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#         .      _      a      b      c      d      i      s      t      v
# 0   False  False  False   True  False  False  False  False  False  False
# 1   False  False  False  False  False  False   True  False  False  False
# 2   False   True  False  False  False  False  False  False  False  False
# 3   False  False  False  False  False   True  False  False  False  False
# 4   False  False   True  False  False  False  False  False  False  False
# 5   False  False  False  False  False  False  False  False   True  False
# 6   False  False   True  False  False  False  False  False  False  False
# 7    True  False  False  False  False  False  False  False  False  False
# 8   False  False  False  False   True  False  False  False  False  False
# 9   False  False  False  False  False  False  False   True  False  False
# 10  False  False  False  False  False  False  False  False  False   True

# %%
# import pandas as pd
import pandas as pd
# load the data with pd.read_csv
gapminder = pd.read_csv("bi_data.csv")
# check the data frame info
print(gapminder.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166 entries, 0 to 165
# Data columns (total 5 columns):
# 타임스탬프                                                                                             166 non-null object
# What genre of music do you most likely to listen to? /가장 좋아하는 음악 장르는 무엇입니까?(Select 3 / 3가지 선택)    166 non-null object
# What kind of fashion style do you like the most? / 가장 좋아하는 패션 스타일은 무엇입니까? (Select 3 / 3가지 선택)     166 non-null object
# What kind of art performances do you like the most? / 가장 좋아하는 공연은 무엇입니까?                          166 non-null object
# What kind of art exhibitions do you like the most? / 가장 좋아하는 전시회는 무엇입니까?                          166 non-null object
# dtypes: object(5)
# memory usage: 6.6+ KB
# None

# %%
>gapminder['What genre of music do you most likely to listen to? /가장 좋아하는 음악 장르는 무엇입니까?(Select 3 / 3가지 선택)'].unique()
array(['Pop (팝)', 'Idol (아이돌)', 'Ballad (발라드)', 'Dance (댄스)', 'Rap/ Hip Hop (랩/힙합)', 'R&B / Soul (R&B/소울)',   'Indie (인디)', 'Rock / Metal (락/메탈)', 'Trot (트로트)'   ], dtype=object)
# Out:
#   File "<ipython-input-7-49714c92ef31>", line 1
#     >gapminder['What genre of music do you most likely to listen to? /가장 좋아하는 음악 장르는 무엇입니까?(Select 3 / 3가지 선택)'].unique()
#     ^
# SyntaxError: invalid syntax

# %%
# import pandas as pd
import pandas as pd
# load the data with pd.read_csv
gapminder = pd.read_csv("bi_data1.csv")
# check the data frame info
print(gapminder.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166 entries, 0 to 165
# Data columns (total 4 columns):
# What genre of music do you most likely to listen to?     166 non-null object
# What kind of fashion style do you like the most?         166 non-null object
# What kind of art performances do you like the most?      165 non-null object
# What kind of art exhibitions do you like the most?       163 non-null object
# dtypes: object(4)
# memory usage: 5.3+ KB
# None

# %%
>gapminder['What genre of music do you most likely to listen to? '].unique()
array(['Pop', 'Idol', 'Ballad','Dance','Rap/ Hip Hop', 'R&B / Soul', 'Indie', 'Rock / Metal', 'Trot'], dtype=object)
# Out:
#   File "<ipython-input-10-c7bb456867d0>", line 1
#     >gapminder['What genre of music do you most likely to listen to? '].unique()
#     ^
# SyntaxError: invalid syntax

# %%
gapminder['What genre of music do you most likely to listen to? '].unique()
array(['Pop', 'Idol', 'Ballad','Dance','Rap/ Hip Hop', 'R&B / Soul', 'Indie', 'Rock / Metal', 'Trot'], dtype=object)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-63749601aaeb> in <module>
#       1 gapminder['What genre of music do you most likely to listen to? '].unique()
# ----> 2 array(['Pop', 'Idol', 'Ballad','Dance','Rap/ Hip Hop', 'R&B / Soul', 'Indie', 'Rock / Metal', 'Trot'], dtype=object)
#
# NameError: name 'array' is not defined

# %%
gapminder['What genre of music do you most likely to listen to? '].unique()
# Out:
# array(['Pop / Idol , Ballad, Dance',
#        'Rap/ Hip Hop, R&B / Soul, Rock / Metal',
#        'Pop, Ballad, R&B / Soul', 'Pop, Rap/Hiphop, Indie',
#        'Idol, Ballad, Dance', 'Pop, Idol, Ballad', 'Pop, Ballad, Indie',
#        'Pop, Dance, Rock / Metal', 'Pop, Rap/Hiphop, R&B / Soul',
#        'Pop, Ballad, Rap/Hiphop', 'Pop, Indie, Rock / Metal',
#        'Rap/Hiphop, R&B / Soul, Indie', 'Rap/Hiphop, Indie, Rock / Metal',
#        'Ballad, Rap/Hiphop, R&B / Soul', 'Pop, Ballad',
#        'Pop, Rap/Hiphop, Rock / Metal', 'Ballad, Rap/Hiphop, Indie',
#        'Pop, Ballad, Dance', 'Pop, R&B / Soul, Rock / Metal',
#        'Dance, Rap/Hiphop, Rock / Metal', 'Idol, Ballad, Indie',
#        'Idol, Dance, R&B / Soul', 'Pop, Idol, Dance',
#        'Pop, Idol, Rock / Metal', 'Idol, Dance, Rap/Hiphop',
#        'Pop, R&B / Soul, Indie', 'Idol, Ballad, Rap/Hiphop',
#        'Pop, Dance, R&B / Soul',
#        'Pop, Ballad, Instrumental, orchestral, ',
# ...

# %%
gapminder['What kind of fashion style do you like the most? '].unique()
# Out:
# array(['Workwear, Techwear, Dandy', 'Casual, Workwear, Street',
#        'Casual, Workwear, Chic', 'Casual, Workwear, Dandy',
#        'Street, Goth, Dandy', 'Casual, Street, Vintage',
#        'Workwear, Street, Dandy', 'Casual, Street, Dandy',
#        'Casual, Grunge, Dandy', 'Casual, Workwear, Techwear',
#        'Street, Grunge, Techwear', 'Street, Vintage, Techwear',
#        'Goth, Techwear', 'Casual, Athleisure, Street',
#        'Casual, Street, Chic', 'Casual, Street, Grunge',
#        'Casual, Workwear, Grunge', 'Workwear, Street, Techwear',
#        'Casual, Street, Techwear', 'Workwear, Preppy, Dandy',
#        'Casual, Vintage, Chic', 'Workwear, Street, Chic',
#        'Workwear, Chic, Grunge', 'Casual, Bohemian, Dandy',
#        'Casual, Workwear, Athleisure', 'Casual, Techwear, Dandy',
#        'Casual, Athleisure, Chic', 'Street, Chic, Bohemian',
#        'Casual, Workwear, Vintage', 'Athleisure, Street, Grunge',
# ...

# %%
gapminder['What kind of art performances do you like the most? '].unique()
# Out:
# array(['Music Performances', 'Musicals', 'Theater',
#        'Interdisciplinary Arts', 'Dance', 'Traditional Art', 'Food', nan,
#        'Animation'], dtype=object)

# %%
gapminder['What kind of art exhibitions do you like the most?'].unique()
# Out:
# array(['Sculptures', 'Paintings', 'Photography', 'Art Design',
#        'Sculptures, Art Design', 'Photography, Art Design, Architecture',
#        'Crafting', 'Paintings, Sculptures, Art Design', nan,
#        'Paintings, Art Design, Architecture', 'Architecture',
#        'Photography, Art Design', 'Paintings, Photography',
#        'Paintings, Sculptures, Photography, Art Design, Architecture',
#        'Art Design, Architecture',
#        'Paintings, Sculptures, Photography, Art Design, Crafting, Architecture',
#        'Paintings, Art Design', 'Crafting, Architecture',
#        'Photography, Crafting, Architecture',
#        'Paintings, Art Design, Crafting', 'Food'], dtype=object)

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#               &      (      )     ,      /      ?      B      C      D  ...  \
# 0   True  False  False  False  True   True  False   True  False   True  ...
# 1   True   True  False  False  True   True  False   True  False  False  ...
# 2   True   True  False  False  True   True  False   True  False  False  ...
# 3   True  False  False  False  True   True  False  False  False  False  ...
# 4   True  False  False  False  True  False  False   True  False   True  ...
# 5   True  False  False  False  True  False  False   True  False  False  ...
# 6   True  False  False  False  True  False  False   True  False  False  ...
# 7   True  False  False  False  True   True  False  False  False   True  ...
# 8   True   True  False  False  True   True  False   True  False  False  ...
# 9   True  False  False  False  True   True  False   True  False  False  ...
# 10  True  False  False  False  True   True  False  False  False  False  ...
# ...

# %%
dataset=(['Sculptures', 'Paintings', 'Photography', 'Art Design',
       'Sculptures, Art Design', 'Photography',
       'Crafting', 'Paintings, Sculptures, Art Design'
       'Paintings, Art Design, Architecture', 'Architecture',
       'Photography, Art Design', 'Paintings, Photography',
       'Paintings, Sculptures, Photography, Art Design, Architecture',
       'Art Design, Architecture',
       'Paintings, Sculptures, Photography, Art Design, Crafting, Architecture',
       'Paintings, Art Design', 'Crafting, Architecture',
       'Photography, Crafting, Architecture',
       'Paintings, Art Design, Crafting', 'Food'], dtype=object)
# Out:
#   File "<ipython-input-25-89f4085967cf>", line 11
#     'Paintings, Art Design, Crafting', 'Food'], dtype=object)
#                                                      ^
# SyntaxError: invalid syntax

# %%
dataset=(['Sculptures', 'Paintings', 'Photography', 'Art Design',
       'Sculptures, Art Design', 'Photography',
       'Crafting', 'Paintings, Sculptures, Art Design'
       'Paintings, Art Design, Architecture', 'Architecture',
       'Photography, Art Design', 'Paintings, Photography',
       'Paintings, Sculptures, Photography, Art Design, Architecture',
       'Art Design, Architecture',
       'Paintings, Sculptures, Photography, Art Design, Crafting, Architecture',
       'Paintings, Art Design', 'Crafting, Architecture',
       'Photography, Crafting, Architecture',
       'Paintings, Art Design, Crafting', 'Food'], dtype=object)
# Out:
#   File "<ipython-input-26-89f4085967cf>", line 11
#     'Paintings, Art Design, Crafting', 'Food'], dtype=object)
#                                                      ^
# SyntaxError: invalid syntax

# %%
dataset=(['Sculptures', 'Paintings', 'Photography', 'Art Design',
       'Sculptures, Art Design', 'Photography',
       'Crafting', 'Paintings, Sculptures, Art Design'
       'Paintings, Art Design, Architecture', 'Architecture',
       'Photography, Art Design', 'Paintings, Photography',
       'Paintings, Sculptures, Photography, Art Design, Architecture',
       'Art Design, Architecture',
       'Paintings, Sculptures, Photography, Art Design, Crafting, Architecture',
       'Paintings, Art Design', 'Crafting, Architecture',
       'Photography, Crafting, Architecture',
       'Paintings, Art Design, Crafting', 'Food'])

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#                ,      A      C      D      F      P      S      a      c  ...  \
# 0   False  False  False  False  False  False  False   True  False   True  ...
# 1   False  False  False  False  False  False   True  False   True  False  ...
# 2   False  False  False  False  False  False   True  False   True  False  ...
# 3    True  False   True  False   True  False  False  False  False  False  ...
# 4    True   True   True  False   True  False  False   True  False   True  ...
# 5   False  False  False  False  False  False   True  False   True  False  ...
# 6   False  False  False   True  False  False  False  False   True  False  ...
# 7    True   True   True  False   True  False   True   True   True   True  ...
# 8   False  False   True  False  False  False  False  False  False   True  ...
# 9    True   True   True  False   True  False   True  False   True  False  ...
# 10   True   True  False  False  False  False   True  False   True  False  ...
# ...

# %%
dataset=([['Pop' , 'Ballad', 'Dance'],
       ['Rap/Hip Hop', 'R&B / Soul', 'Rock / Metal'],
       ['Pop', 'Ballad', 'R&B / Soul'], ['Pop', 'Rap/Hiphop', 'Indie'],
       ['Idol', 'Ballad', 'Dance'], ['Pop', 'Idol', 'Ballad'], ['Pop', 'Ballad', 'Indie'],
       ['Pop', 'Dance', 'Rock / Metal'], ['Pop', 'Rap/Hiphop', 'R&B / Soul'],
       ['Pop', 'Ballad', 'Rap/Hiphop'], ['Pop', 'Indie', 'Rock / Metal'],
       ['Rap/Hiphop', 'R&B / Soul', 'Indie'], ['Rap/Hiphop', 'Indie', 'Rock / Metal'],
       ['Ballad', 'Rap/Hiphop', 'R&B / Soul'], ['Pop', 'Ballad'],
       ['Pop', 'Rap/Hiphop', 'Rock / Metal'], ['Ballad', 'Rap/Hiphop', 'Indie'],
       ['Pop', 'Ballad', 'Dance'], ['Pop', 'R&B / Soul', 'Rock / Metal'],
       ['Dance', 'Rap/Hiphop', 'Rock / Metal'], ['Idol', 'Ballad', 'Indie'],
       ['Idol', 'Dance', 'R&B / Soul'], ['Pop', 'Idol', 'Dance'],
       ['Pop', 'Idol', 'Rock / Metal'], ['Idol', 'Dance', 'Rap/Hiphop'],
       ['Pop', 'R&B / Soul', 'Indie'], ['Idol', 'Ballad', 'Rap/Hiphop'],
       ['Pop', 'Dance', 'R&B / Soul'],
       ['Pop', 'Ballad', 'Instrumental', 'orchestral'],
       ['Idol', 'Ballad', 'R&B / Soul'], ['Pop', 'Dance'],
       ['Pop', 'Indie'], ['Idol', 'Dance', 'Rock / Metal'],
       ['Pop', 'Idol', 'Trot'], ['Pop', 'Idol', 'R&B / Soul'],
       ['Pop', 'Idol', 'Rap/Hiphop'], ['Ballad', 'R&B / Soul', 'Chinese'],
       ['Pop', 'Ballad', 'Rock / Metal'], ['Pop', 'Rock / Metal', 'EDM'],
       ['Ballad', 'Dance', 'Rap/Hiphop'], ['Pop', 'Dance', 'Indie'],
       ['Ballad', 'R&B / Soul', 'Indie'], ['Dance', 'Rap/Hiphop', 'R&B / Soul'],
       ['Pop', 'Rock / Metal'],
       ['Ballad', 'Dance', 'R&B / Soul'], ['Pop', 'Dance', 'Rap/Hiphop'],
       ['Pop', 'Idol', 'Indie'], ['Dance', 'Rap/Hiphop', 'Indie'],
       ['Pop', 'Indie', 'alternative'], ['Idol', 'Rap/Hiphop', 'R&B / Soul'],
       ['Pop', 'Indie', 'Lofi '], ['Idol', 'R&B / Soul', 'Indie'],
       ['Pop', 'Rap/Hiphop', 'EDM'], ['Idol', 'Dance', 'Indie']])

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#     Ballad  Chinese  Dance    EDM   Idol  Indie  Instrumental  Lofi     Pop  \
# 0     True    False   True  False  False  False         False  False   True
# 1    False    False  False  False  False  False         False  False  False
# 2     True    False  False  False  False  False         False  False   True
# 3    False    False  False  False  False   True         False  False   True
# 4     True    False   True  False   True  False         False  False  False
# 5     True    False  False  False   True  False         False  False   True
# 6     True    False  False  False  False   True         False  False   True
# 7    False    False   True  False  False  False         False  False   True
# 8    False    False  False  False  False  False         False  False   True
# 9     True    False  False  False  False  False         False  False   True
# 10   False    False  False  False  False   True         False  False   True
# ...

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#     Ballad  Chinese  Dance    EDM   Idol  Indie  Instrumental  Lofi     Pop  \
# 0     True    False   True  False  False  False         False  False   True
# 1    False    False  False  False  False  False         False  False  False
# 2     True    False  False  False  False  False         False  False   True
# 3    False    False  False  False  False   True         False  False   True
# 4     True    False   True  False   True  False         False  False  False
# 5     True    False  False  False   True  False         False  False   True
# 6     True    False  False  False  False   True         False  False   True
# 7    False    False   True  False  False  False         False  False   True
# 8    False    False  False  False  False  False         False  False   True
# 9     True    False  False  False  False  False         False  False   True
# 10   False    False  False  False  False   True         False  False   True
# ...

# %%
from mlxtend.frequent_patterns import fpgrowth

fpgrowth(df, min_support=0.6)
# Out:
# Empty DataFrame
# Columns: [support, itemsets]
# Index: []

# %%
from mlxtend.frequent_patterns import fpgrowth

fpgrowth(df, min_support=0.5)
